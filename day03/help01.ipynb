# %%
import pandas as pd
import numpy as np
# !move C:\\Users\\i7B\\Downloads\\stationery.csv

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5016-EF76
#
#  C:\Users\i7B\np_pd\day03 디렉터리
#
# 2020-05-28  오후 05:52    <DIR>          .
# 2020-05-28  오후 05:52    <DIR>          ..
# 2020-05-28  오후 05:42    <DIR>          .ipynb_checkpoints
# 2020-05-28  오후 05:52            26,684 help01.ipynb
# 2020-05-28  오전 11:23           153,105 lesson01.ipynb
# 2020-05-28  오후 02:13            79,607 lesson02.ipynb
# 2020-05-28  오후 03:11            33,653 lesson03.ipynb
# 2020-05-28  오후 03:31            11,717 lesson04.ipynb
# 2020-05-28  오후 05:34           397,159 lesson05.ipynb
# 2018-12-26  오후 08:56                43 read_csv_sample.csv
# 2020-05-28  오후 12:12               105 read_csv2_sample.csv
# 2018-12-29  오후 01:58               472 read_json_sample.json
# 2019-01-08  오후 06:22             1,103 sample.html
# 2020-05-28  오전 10:55               466 stationery.csv
# 2020-05-28  오후 03:20                95 write_sample.csv
# 2020-05-28  오후 03:20               200 write_sample.json
# 2020-05-28  오후 03:29             6,120 write_sample.xlsx
# 2018-12-27  오전 06:35            11,662 남북한발전전력량.xlsx
# 2019-01-13  오후 10:36            86,316 시도별 전출입 인구수.xlsx
#               16개 파일             808,507 바이트
#                3개 디렉터리  57,687,941,120 바이트 남음

# %%
df=pd.read_csv("stationery.csv")
df
# Out:
#          date    place      name product_name  unit_stock  unit  \
# 0   5/14/2020  Central      Gill       Pencil       100.0    53
# 1   6/17/2020  Central    Kivell         Desk         NaN     5
# 2    7/4/2020     East     Jones      Pen Set       100.0    62
# 3   7/21/2020  Central    Morgan      Pen Set       100.0    55
# 4   8/24/2020     West   Sorvino         Desk       100.0     3
# 5  10/14/2020     West  Thompson       Binder         NaN    57
# 6  10/31/2020  Central   Andrews       Pencil       100.0    14
# 7  11/17/2020  Central   Jardine       Binder         NaN    11
#
#    price_per_unit totla_price
# 0            1.29       68.37
# 1          125.00         625
# 2            4.99      309.38
# 3           12.49      686.95
# 4          275.00         825
# 5           19.99    1,139.43
# 6            1.29       18.06
# 7            4.99       54.89

# %%
a=df.fillna(value=0)
a
# Out:
#          date    place      name product_name  unit_stock  unit  \
# 0   5/14/2020  Central      Gill       Pencil       100.0    53
# 1   6/17/2020  Central    Kivell         Desk         0.0     5
# 2    7/4/2020     East     Jones      Pen Set       100.0    62
# 3   7/21/2020  Central    Morgan      Pen Set       100.0    55
# 4   8/24/2020     West   Sorvino         Desk       100.0     3
# 5  10/14/2020     West  Thompson       Binder         0.0    57
# 6  10/31/2020  Central   Andrews       Pencil       100.0    14
# 7  11/17/2020  Central   Jardine       Binder         0.0    11
#
#    price_per_unit totla_price
# 0            1.29       68.37
# 1          125.00         625
# 2            4.99      309.38
# 3           12.49      686.95
# 4          275.00         825
# 5           19.99    1,139.43
# 6            1.29       18.06
# 7            4.99       54.89

# %%
from matplotlib.patches import Ellipse
from matplotlib import pyplot as plt
from sympy import Symbol
ellipse = Ellipse(xy=(0,0), width=10, height=5, edgecolor='r', fc='None', lw=2)
fig, ax = plt.subplots()

ax.add_patch(ellipse)
ax.set_aspect('equal')
ax.autoscale()
plt.show()

# %%
x=Symbol('x')
# Out:
# x
