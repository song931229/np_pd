# %%
import shutil

# %%
# shutil.move ('C:/Users/i7B/Downloads/month.xlsx','cleanair.xlsx')
# Out:
# 'cleanair.xlsx'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
# %matplotlib inline
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)
# %config InlineBackend.figure_format = 'retina'

# %%
df=pd.read_excel('cleanair.xlsx',header=4)

# %%
df.head()
# Out:
#        구분  Unnamed: 1  1월  2월  3월  4월  5월  6월  7월  8월    9월  10월  11월  12월
# 0  서울시 평균          24  38  35  45  21  29  20  19  16  12.0   15   20   29
# 1     강남구          25  43  40  47  18  26  16  18  17  11.0   14   19   27
# 2     강동구          26  42  39  44  18  27  18  19  18  13.0   17   25   37
# 3     강북구          25  39  35  42  16  25  17  20  17  13.0   18   21   32
# 4     강서구          26  37  35  46  19  27  18  21  19  13.0   17   25   30

# %%
df=df.drop(0)

# %%
df.head()
# Out:
#     구분  Unnamed: 1  1월  2월  3월  4월  5월  6월  7월  8월    9월  10월  11월  12월
# 1  강남구          25  43  40  47  18  26  16  18  17  11.0   14   19   27
# 2  강동구          26  42  39  44  18  27  18  19  18  13.0   17   25   37
# 3  강북구          25  39  35  42  16  25  17  20  17  13.0   18   21   32
# 4  강서구          26  37  35  46  19  27  18  21  19  13.0   17   25   30
# 5  관악구          28  42  39  50  27  34  23  15  13   NaN   15   20   28

# %%
df.count()
# Out:
# 구분            25
# Unnamed: 1    25
# 1월            25
# 2월            25
# 3월            25
# 4월            25
# 5월            25
# 6월            25
# 7월            25
# 8월            25
# 9월            24
# 10월           25
# 11월           25
# 12월           25
# dtype: int64

# %%
df=df.rename(columns={'Unnamed: 1':'평균'})

# %%
df.head()
# Out:
#     구분  평균  1월  2월  3월  4월  5월  6월  7월  8월    9월  10월  11월  12월
# 1  강남구  25  43  40  47  18  26  16  18  17  11.0   14   19   27
# 2  강동구  26  42  39  44  18  27  18  19  18  13.0   17   25   37
# 3  강북구  25  39  35  42  16  25  17  20  17  13.0   18   21   32
# 4  강서구  26  37  35  46  19  27  18  21  19  13.0   17   25   30
# 5  관악구  28  42  39  50  27  34  23  15  13   NaN   15   20   28

# %%
plt.figure(figsize=(15,10))
plt.bar(df['구분'],df['평균'])
# Out:
# <BarContainer object of 25 artists>

# %%
df=df.set_index('구분')

# %%
plt.figure(figsize=(15,10))
for x in range(25):
    plt.plot(df.columns,df.iloc[x])
plt.legend(df.index)
plt.show()
