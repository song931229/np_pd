# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%82%A0%EC%94%A8'

resp=requests.get(url)
soup=BeautifulSoup(resp.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
a=soup.find('ul',class_='list_area')

# %%
b=a.find_all('li')

# %%
for x in b:
    print(x.find_all('span')[0].get_text(),x.find_all('span')[4].get_text().strip())
# Out:
# 26 11시
# 27 12시
# 28 13시
# 28 14시
# 29 15시
# 27 18시
# 24 21시
# 21 내일
