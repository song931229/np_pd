# %%
import requests

# %%
import json

# %%
url_change=['RESERVE','CURRENT','COMMING','BOXOFFICE','POINT']

# %%
for url in url_change:
    json_url='https://movie.naver.com/movieChartJson.nhn?type='+url
    headers={'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'ajax': 'true',
    'charset': 'utf-8',
    'content-type': 'application/x-www-form-urlencoded; charset=utf-8',
    'cookie': 'NNB=4CHKQBVY6LPF4; nx_ssl=2; NRTK=ag#20s_gr#2_ma#-2_si#1_en#0_sp#0; SL_GWPT_Show_Hide_tmp=1; SL_wptGlobTipTmp=1; csrf_token=affe378e-e0e6-459c-974b-69e8cca6f909; BMR=s=1591929791549&r=https%3A%2F%2Fm.blog.naver.com%2Fimmeoroo%2F221303343224&r2=https%3A%2F%2Fwww.google.com%2F; NV_WETR_LOCATION_RGN_M="MDkxNDAxMDQ="; NV_WETR_LAST_ACCESS_RGN_M="MDkxNDAxMDQ="; page_uid=UXKKAwp0J1ZssB2xqJ4ssssstQd-505040; NM_VIEWMODE_AUTO=wide',
    'referer': 'https://movie.naver.com/',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest'}
    json_string = requests.get(json_url,headers=headers).text
    data_list = json.loads(json_string)
    print(url)
    print()
    for x in range(10):
        print(data_list['movieChartList'][url][x]['movieTitle'])
    print('-----------------------------')
# Out:
# RESERVE
#
# 결백
# 침입자
# 나의 첫 번째 슈퍼스타
# 에어로너츠
# 위대한 쇼맨
# 콜 미 바이 유어 네임
# 루팡 3세: 더 퍼스트
# 너는 달밤에 빛나고
# 슈퍼스타 뚜루
# 들리나요?
# -----------------------------
# CURRENT
#
# 레옹 디 오리지널
# 도미노
# 콜 미 바이 유어 네임
# 환상의 마로나
# 전망 좋은 방
# 파리 오페라 발레단
# 백년의 기억
# 레옹
# 결백
# 에어로너츠
# -----------------------------
# COMMING
#
# 야구소녀
# 온워드: 단 하루의 기적
# 기도의 힘
# 사라진 시간
# 바다로 가자
# 아이 캔 온리 이매진
# 에이브의 쿠킹 다이어리
# 인비저블 라이프
# #살아있다
# 007 노 타임 투 다이
# -----------------------------
# BOXOFFICE
#
# 침입자
# 위대한 쇼맨
# 언더워터
# 프리즌 이스케이프
# 매드맥스: 분노의 도로
# 카페 벨에포크
# 프랑스여자
# 슈퍼스타 뚜루
# 라이프 오브 파이
# 미스비헤이비어
# -----------------------------
# POINT
#
# 들리나요?
# 아이즈 온 미 : 더 무비
# 안녕, 미누
# 가버나움
# 첫사랑
# 환상의 마로나
# 비홀드 마이 하트
# 나는보리
# 위대한 쇼맨
# 레옹
# -----------------------------

# %%
data_list
# Out:
# {'movieChartList': {'RESERVE': [{'movieCode': 180378,
#     'movieTitle': '결백',
#     'posterImageUrl': '/20200610_45/1591752004615kLWYv_JPEG/movie_image.jpg',
#     'weekendAudience': 0,
#     'openDate': None,
#     'pointSum': 0,
#     'joinNumber': 0,
#     'reserveRatio': 44.33,
#     'saleRate': None,
#     'salePossibleYn': False,
#     'lendingPossibleYn': False,
#     'adult': False,
#     'korGradeList': [{'code': '1001003', 'name': '15세 관람가'}],
#     'lastKoreanGrade': {'code': '1001003', 'name': '15세 관람가'},
#     'usGradeList': [],
#     'lastUsGrade': None,
#     'theater': 0,
#     'formattedWeekendAudience': '0',
#     'point': '0.00',
#     'formattedReserveRatio': '44.33',
#     'formattedSaleRate': '0.00'},
#    {'movieCode': 182835,
#     'movieTitle': '침입자',
#     'posterImageUrl': '/20200604_287/1591247101011RnPbV_JPEG/movie_image.jpg',
#     'weekendAudience': 0,
#     'openDate': None,
#     'pointSum': 0,
#     'joinNumber': 0,
#     'reserveRatio': 22.08,
# ...

# %%
data_list['movieChartList']['POINT']
# Out:
# [{'movieCode': 193136,
#   'movieTitle': '들리나요?',
#   'posterImageUrl': '/20200513_25/1589345579187CsszV_JPEG/movie_image.jpg',
#   'weekendAudience': 0,
#   'openDate': '20200610',
#   'pointSum': 306,
#   'joinNumber': 31,
#   'reserveRatio': None,
#   'saleRate': None,
#   'salePossibleYn': False,
#   'lendingPossibleYn': False,
#   'adult': False,
#   'korGradeList': [{'code': '1001001', 'name': '전체 관람가'}],
#   'lastKoreanGrade': {'code': '1001001', 'name': '전체 관람가'},
#   'usGradeList': [],
#   'lastUsGrade': None,
#   'theater': 147,
#   'formattedWeekendAudience': '0',
#   'point': '9.87',
#   'formattedReserveRatio': '0.00',
#   'formattedSaleRate': '0.00'},
#  {'movieCode': 189027,
#   'movieTitle': '아이즈 온 미 : 더 무비',
#   'posterImageUrl': '/20200520_183/1589935657986pCYTG_JPEG/movie_image.jpg',
#   'weekendAudience': 0,
#   'openDate': '20200610',
#   'pointSum': 5543,
#   'joinNumber': 564,
#   'reserveRatio': None,
#   'saleRate': None,
#   'salePossibleYn': False,
# ...

# %%
# Out:
# 결백
# 침입자
# 나의 첫 번째 슈퍼스타
# 에어로너츠
# 위대한 쇼맨
# 콜 미 바이 유어 네임
# 루팡 3세: 더 퍼스트
# 너는 달밤에 빛나고
# 슈퍼스타 뚜루
# 들리나요?

# %%
requests.get?

# %%
from matplotlib import pyplot as plt

# %%
plt.bar()
