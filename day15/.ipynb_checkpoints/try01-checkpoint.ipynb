# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url='https://news.naver.com/main/ranking/popularDay.nhn?mid=etc&sid1=111'

# %%
page=requests.get(url)

# %%
page_soup=BeautifulSoup(page.text,'html.parser')

# %%
page_soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="telephone=no" name="format-detection">
# <meta content="많이 본 뉴스 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="기사의 조회 수를 각 섹션 기준으로 집계하여 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="많이 본 뉴스 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
atags=page_soup.find_all('a',{'class':'nclicks(rank.tabsec2)'})

# %%
the_codes={}

# %%
for atag in atags:
    try:
        the_codes[re.search('ionId=([0-9]{3})',atag['href'])[1]]=[atag.get_text()[:-3]]
    except:
        print(atag)
# Out:
# <a class="nclicks(rank.tabsec2)" href="/main/ranking/popularDay.nhn?rankingType=popular_day&amp;date=20200622">종합<span class="blind">선택됨</span></a>

# %%
the_codes
# Out:
# {'100': ['정치'],
#  '101': ['경제'],
#  '102': ['사회'],
#  '103': ['생활/문화'],
#  '104': ['세계'],
#  '105': ['IT/과학'],
#  '003': ['포토'],
#  '115': ['TV']}

# %%
for code in the_codes:
    params = {'rankingType': 'popular_day',
    'sectionId': code,
    'date': '20200622'}
    sub_page=requests.get('https://news.naver.com/main/ranking/popularDay.nhn',params=params)
    sub_soup=BeautifulSoup(sub_page.content,"html.parser")
    view_counts=sub_soup.find_all('div',{'class':'ranking_view'})
    if len(view_counts)==0:
        view_counts=sub_soup.find_all('div',{'class':'count_view'})
    cosum=0
    for view_count in view_counts:
        cosum+=int(view_count.get_text().replace(',',''))
    the_codes[code].append(cosum)

# %%
the_codes
# Out:
# {'100': ['정치', 482995],
#  '101': ['경제', 258310],
#  '102': ['사회', 851585],
#  '103': ['생활/문화', 221390],
#  '104': ['세계', 235810],
#  '105': ['IT/과학', 104464],
#  '003': ['포토', 1043738],
#  '115': ['TV', 145946]}

# %%
import pandas as pd

# %%
df=pd.DataFrame(the_codes)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)
# %config InlineBackend.figure_format = 'retina'

# %%
df.columns=df.iloc[0,:]

# %%
plt.bar(df.columns,df.iloc[1,:])
plt.title("센션별 조회수 합계")
plt.xlabel("섹션")
plt.ylabel("조회수 합계")
plt.savefig("sections_counts")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-20ec49b34065> in <module>
#       3 plt.xlabel("섹션")
#       4 plt.ylabel("조회수 합계")
# ----> 5 plt.savefig()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# TypeError: savefig() missing 1 required positional argument: 'fname'

# %%
the_codes2={}

# %%
for atag in atags:
    try:
        the_codes2[re.search('ionId=([0-9]{3})',atag['href'])[1]]=[atag.get_text()[:-3]]
    except:
        print(atag)
# Out:
# <a class="nclicks(rank.tabsec2)" href="/main/ranking/popularDay.nhn?rankingType=popular_day&amp;date=20200622">종합<span class="blind">선택됨</span></a>

# %%
the_codes2
# Out:
# {'100': ['정치'],
#  '101': ['경제'],
#  '102': ['사회'],
#  '103': ['생활/문화'],
#  '104': ['세계'],
#  '105': ['IT/과학'],
#  '003': ['포토'],
#  '115': ['TV']}

# %%
for code in the_codes2:
    params = {'rankingType': 'popular_day',
    'sectionId': code,
    'date': '20200622'}
    sub_page=requests.get('https://news.naver.com/main/ranking/popularDay.nhn',params=params)
    sub_soup=BeautifulSoup(sub_page.content,"html.parser")
    offices=sub_soup.find_all('div',{'class':'ranking_office'})
    if len(view_counts)==0:
        continue
    pool=[]
    for office in offices:
        pool.append(office.get_text())
    the_codes2[code].append(pool)

# %%
the_codes2
# Out:
# {'100': ['정치',
#   ['서울경제',
#    '헤럴드경제',
#    '서울신문',
#    '조선일보',
#    '머니투데이',
#    '조선일보',
#    '한국경제',
#    '중앙일보',
#    '중앙일보',
#    '연합뉴스',
#    '세계일보',
#    '파이낸셜뉴스',
#    '서울신문',
#    '조선일보',
#    '경향신문',
#    '중앙일보',
#    '헤럴드경제',
#    '한국경제',
#    '경향신문',
#    'SBS',
#    '아시아경제',
#    '연합뉴스',
#    'TV조선',
#    'YTN',
#    '경향신문',
#    '중앙일보',
#    '한국일보',
#    'YTN',
#    '서울경제',
#    '한국경제']],
#  '101': ['경제',
#   ['국민일보',
#    '경향신문',
#    '한국경제',
#    '매일경제',
#    '중앙일보',
#    '머니투데이',
#    'SBS',
#    '조선일보',
#    '중앙일보',
#    '이코노미스트',
#    '연합뉴스TV',
#    '아시아경제',
#    '아시아경제',
#    '머니투데이',
#    '머니투데이',
#    '한국경제TV',
#    '이데일리',
#    '뉴스1',
#    '머니투데이',
#    'JTBC',
#    '한국경제',
#    '헤럴드경제',
#    '중앙일보',
#    '한국경제',
#    '조선일보',
#    'YTN',
#    '이코노미스트',
#    '한국경제TV',
#    '아시아경제',
#    '한국경제']],
#  '102': ['사회',
#   ['한국경제',
#    'SBS',
#    '시사저널',
#    '뉴시스',
#    '연합뉴스',
#    '한국경제TV',
#    '국민일보',
#    '연합뉴스',
#    '중앙일보',
#    '서울신문',
#    '아시아경제',
# ...

# %%
import collections

# %%
countlist={}

# %%
for x in the_codes2:
    countlist[x]=collections.Counter(the_codes2[x][1])

# %%
countlist
# Out:
# {'100': Counter({'서울경제': 2,
#           '헤럴드경제': 2,
#           '서울신문': 2,
#           '조선일보': 3,
#           '머니투데이': 1,
#           '한국경제': 3,
#           '중앙일보': 4,
#           '연합뉴스': 2,
#           '세계일보': 1,
#           '파이낸셜뉴스': 1,
#           '경향신문': 3,
#           'SBS': 1,
#           '아시아경제': 1,
#           'TV조선': 1,
#           'YTN': 2,
#           '한국일보': 1}),
#  '101': Counter({'국민일보': 1,
#           '경향신문': 1,
#           '한국경제': 4,
#           '매일경제': 1,
#           '중앙일보': 3,
#           '머니투데이': 4,
#           'SBS': 1,
#           '조선일보': 2,
#           '이코노미스트': 2,
#           '연합뉴스TV': 1,
#           '아시아경제': 3,
#           '한국경제TV': 2,
#           '이데일리': 1,
#           '뉴스1': 1,
#           'JTBC': 1,
#           '헤럴드경제': 1,
#           'YTN': 1}),
#  '102': Counter({'한국경제': 1,
#           'SBS': 1,
#           '시사저널': 1,
#           '뉴시스': 1,
#           '연합뉴스': 5,
#           '한국경제TV': 1,
#           '국민일보': 3,
#           '중앙일보': 4,
#           '서울신문': 2,
# ...

# %%
df_of=pd.DataFrame(countlist)

# %%
df_of
# Out:
#              100  101  102  103  104  105  003  115
# 서울경제         2.0  NaN  NaN  1.0  1.0  NaN  NaN  NaN
# 헤럴드경제        2.0  1.0  NaN  NaN  NaN  1.0  NaN  NaN
# 서울신문         2.0  NaN  2.0  2.0  1.0  3.0  NaN  NaN
# 조선일보         3.0  2.0  4.0  2.0  1.0  3.0  NaN  NaN
# 머니투데이        1.0  4.0  NaN  1.0  2.0  NaN  NaN  NaN
# 한국경제         3.0  4.0  1.0  5.0  1.0  3.0  NaN  NaN
# 중앙일보         4.0  3.0  4.0  3.0  5.0  NaN  NaN  NaN
# 연합뉴스         2.0  NaN  5.0  3.0  2.0  2.0  NaN  NaN
# 세계일보         1.0  NaN  NaN  NaN  1.0  NaN  NaN  NaN
# 파이낸셜뉴스       1.0  NaN  NaN  2.0  1.0  2.0  NaN  NaN
# 경향신문         3.0  1.0  NaN  1.0  1.0  NaN  NaN  NaN
# SBS          1.0  1.0  1.0  NaN  NaN  NaN  NaN  NaN
# 아시아경제        1.0  3.0  1.0  NaN  1.0  1.0  NaN  NaN
# TV조선         1.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# YTN          2.0  1.0  NaN  NaN  1.0  NaN  NaN  NaN
# 한국일보         1.0  NaN  NaN  NaN  2.0  NaN  NaN  NaN
# 국민일보         NaN  1.0  3.0  NaN  2.0  1.0  NaN  NaN
# ...

# %%
df_of.drop(axis=1,columns=['003','115'],inplace=True)

# %%
fig,axs=plt.subplots(nrows=3,ncols=2,figsize=(15,20))
axs[0][0].bar(df_of['100'].dropna().index,df_of['100'].dropna())
axs[0][1].bar(df_of['101'].dropna().index,df_of['101'].dropna())
axs[1][0].bar(df_of['102'].dropna().index,df_of['102'].dropna())
axs[1][1].bar(df_of['103'].dropna().index,df_of['103'].dropna())
axs[2][0].bar(df_of['104'].dropna().index,df_of['104'].dropna())
axs[2][1].bar(df_of['105'].dropna().index,df_of['105'].dropna())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-03435f086bae> in <module>
#       1 fig,axs=plt.subplots(nrows=3,ncols=2,figsize=(15,20))
#       2 axs[0][0].bar(df_of['100'].dropna().index,df_of['100'].dropna())
# ----> 3 axs[0][0].title("asd")
#       4 axs[0][1].bar(df_of['101'].dropna().index,df_of['101'].dropna())
#       5 axs[1][0].bar(df_of['102'].dropna().index,df_of['102'].dropna())
#
# TypeError: 'Text' object is not callable

# %%
ages={}
for x in range(10,70,10):
    ages[str(x)]=[str(x)+'대']

# %%
for age in ages:
    params = {'rankingType': 'age',
    'subType': age,
    'date': '20200615'}
    sub_page=requests.get('https://news.naver.com/main/ranking/popularDay.nhn',params=params)
    sub_soup=BeautifulSoup(sub_page.content,"html.parser")
    view_counts=sub_soup.find_all('div',{'class':'ranking_view'})
    if len(view_counts)==0:
        view_counts=sub_soup.find_all('div',{'class':'count_view'})
    cosum=0
    for view_count in view_counts:
        cosum+=int(view_count.get_text().replace(',',''))
    ages[age].append(cosum)

# %%
ages
# Out:
# {'10': ['10대', 1703],
#  '20': ['20대', 52887],
#  '30': ['30대', 62421],
#  '40': ['40대', 78497],
#  '50': ['50대', 47487],
#  '60': ['60대', 27090]}

# %%
df2=pd.DataFrame(ages)

# %%
df2
# Out:
#      10     20     30     40     50     60
# 0   10대    20대    30대    40대    50대    60대
# 1  1703  52887  62421  78497  47487  27090

# %%
df2.columns=df2.iloc[0,:]

# %%
plt.bar(df2.columns,df2.iloc[1,:])
# Out:
# <BarContainer object of 6 artists>

# %%
import wordcloud
from wordcloud import WordCloud

# %%
import random

# %%
ga=['가','나','다','라','마','바','사','아','자','차','카','타','파','하']

# %%
nums=[ga[random.randrange(len(ga))]+ga[random.randrange(len(ga))] for x in range(10000)]

# %%
nums_joined=' '.join(nums)

# %%
wordcloud = WordCloud(font_path='C:\Windows\Fonts\malgun.ttf',background_color='white').generate(nums_joined)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()
