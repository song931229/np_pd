# %%
import requests
from bs4 import BeautifulSoup

# %%
sauce_url='https://www.epeople.go.kr/frmSub/pttn/openPttnList.npaid'

# %%
sauce_header={
# 'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
# 'Accept-Encoding': 'gzip, deflate, br',
# 'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
# 'Cache-Control': 'max-age=0',
# 'Connection': 'keep-alive',
# 'Content-Length': '1105',
# 'Content-Type': 'application/x-www-form-urlencoded',
'Cookie': '_xm_webid_1_=160914436; JSESSIONID=RYIG9IxfTivU+mlZ0rhzlAyI.euser34; SL_GWPT_Show_Hide_tmp=1; SL_wptGlobTipTmp=1',#*
# 'Host': 'www.epeople.go.kr',
# 'Origin': 'https://www.epeople.go.kr',
# 'Referer': 'https://www.epeople.go.kr/frmSub/pttn/openPttnList.npaid',
# 'Sec-Fetch-Dest': 'document',
# 'Sec-Fetch-Mode': 'navigate',
# 'Sec-Fetch-Site': 'same-origin',
# 'Sec-Fetch-User': '?1',
# 'Upgrade-Insecure-Requests': '1',
# 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
}

# %%
sauce_form={
# 'recordCountPerPage': '10',
# 'pageIndex': '1',
# 'bestInstPttnClsfCd': 'all',
# 'searchWordType': 1,
'rqstStDt': '2020-05-01',
'rqstEndDt': '2020-06-15',
'frm_frmMenuMngNo': 'WBF-1703-000232',#*

}

# %%
page=requests.post(sauce_url,data=sauce_form,headers=sauce_header)

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="_csrf" name="_csrf_parameter"><meta content="X-CSRF-TOKEN" name="_csrf_header"><meta content="ba995069-83ae-4d88-a646-c8036085dac3" name="_csrf">
# <title>국민신문고</title>
# <link href="/resource/css/paid/nep/pot/css.css?t_=20200618_1639" rel="stylesheet" type="text/css"/>
# <link href="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css"/>
# <link href="/resource/css/paid/cmmn/jAlert.css" rel="stylesheet" type="text/css"/>
# <script src="/resource/js/paid/cmmn/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.cookie.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/bootstrap.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/loading.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/sendAjaxReq.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.form.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.concat.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/pgwslideshow/pgwslideshow.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/pot/common.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.money.plus.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alphanumeric.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alerts.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/validation.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.file.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.popup.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/cmmn/common.sch.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/pot/kakao.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var contexts = '';
# var JBOSS_NODE_NAME = 'euser34';
#
# var acesMode = 'frm';  //프레임 접근 구분자
# $(function(){
# 	if (acesMode == 'frm') {
# 		$('#contentWrap').addClass('full');  //프레임일 경우 화면 레이아웃 Full
# 	}
# });
#
#
# Kakao.init('53056da5f179f887698576ec42f7468a');
#
# function fn_kakaoLink(title, pageUrl) {
# 	title = "국민신문고 | " + title;
#
#     Kakao.Link.sendDefault({
#       objectType: 'text',
#       text: title,
#       link: {
#         mobileWebUrl: pageUrl,
#         webUrl: pageUrl
#       },
#       buttons: [
#         {
#           title: '웹으로 이동',
#           link: {
#             mobileWebUrl: pageUrl,
#             webUrl: pageUrl
#           }
#         }
#       ]
#     });
#
# }
# </script>
# </meta></meta></meta></head>
# <body>
# <div class="loading black" style="position:fixed; width:100%; height:auto; min-height:100%; z-index:100; top:0; left:0; display:block; opacity:.6;">
# <div style="width:100%; height:100%; top:50%; left:50%; position:absolute;">
# <span style="display:table-cell; text-align:center; vertical-align:middle;">
# <img alt="로딩이미지" src="/resource/images/paid/cmmn/bg_progress.gif"/>
# </span>
# </div>
# </div>
# <div id="wrap">
# <!-- 세션에 접근 시스템 구분자가 프레임이 아닐 경우(프레임 통합 메뉴로 접근시 세션에 접근 시스템 구분자를 추가)만 헤더와 푸터를 포함하도록 처리 -->
# <div id="containerAcc"></div>
# <main id="container">
# <div class="layout">
# <section id="contentWrap">
# <script>
# 		//프레임 전용 공개민원 목록 페이지
# 		//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 시작
# 		var frm_frmMenuMngNo = 'WBF-1703-000232';  //프레임메뉴관리번호
# 		var frm_instCd = '';  //기관코드
# 		var frm_clsfAplcYn = '';  //민원분류적용여부
# 		//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 끝
#
# 		$(document).ready(function() {
#
#
# 			// 기간 달력 날짜 제어
# 			cfn_dateTerm("rqstStDt", "rqstEndDt");
#
# 			// 검색조건 유지
# 			var searchWordType = '';
# 			var pttnTypeNm = '1';
# 			var searchInstType = 'frm';
# 			var searchInstCd = 'all';
# 			var bestInstPttnClsfCd = '';
# 			var rcptInstMenuCd = '';
# 			var rsltMenuList = "[]";
#
#
# 			if(searchWordType == ""){
# 				searchWordType = "1";
# 			}
#
# 			$('#searchWordType').val(searchWordType).prop("selected", true);
#
# 			// 민원분류적용여부
# 			if(frm_clsfAplcYn == 'Y'){
# 				$('#div_bestInstPttnClsfCd').show();
# 				if (bestInstPttnClsfCd != "") {
# 					$('#bestInstPttnClsfCd').val(bestInstPttnClsfCd).prop("selected", true);
# 				}
# 			}
#
# 			if(rsltMenuList != "" && rsltMenuList != null){
# 				$('#div_rcptInstMenuCd').show();
# 				if(rcptInstMenuCd != ""){
# 					$('#rcptInstMenuCd').val(rcptInstMenuCd).prop("selected", true);
# 				}
# 			}
#
# 			//20191115/통합연계 김정원/프레임통합메뉴 관련 스크립트 추가 시작
# 			if ($.chkEmptyVal(frm_frmMenuMngNo)) {  //세션에 프레임메뉴관리번호가 존재하면 프레임통합메뉴로 인증 후 접근한 것
#
# 				$('#searchInstType').val("frm");  //기관구분
# 				$('#searchInstCd').val("all");  //기관코드
# 				$('#lcgovBlngInstCd').val(frm_instCd);  //소속기관코드
#
# 			}
#
# 		});
#
#
# 		//날짜조건별 달력셋팅
# 		function rqstDateSelect(){
# 			var dateTypeValue =  $("#dateType").val();
# 			var rqstSearchDt= new Date();
# 			var nowYear = rqstSearchDt.getFullYear().toString();
# 			var nowMonth = (rqstSearchDt.getMonth()+1).toString();
# 			var nowDay = rqstSearchDt.getDate().toString();
# 			if(nowMonth < 10){
# 				nowMonth = "0"+nowMonth;
# 			}
# 			if(nowDay < 10){
# 				nowDay = "0"+nowDay;
# 			}
# 			var toDay = nowYear+"-"+nowMonth+"-"+nowDay;
# 			$("#rqstEndDt").val(toDay);
# 			if(dateTypeValue == 0){
# 				var rqstSearch = rqstSearchDt.getTime() - (365*1*24*60*60*1000);
# 				rqstSearchDt.setTime(rqstSearch);
# 				var yearYear = rqstSearchDt.getFullYear().toString();
# 				var yearMonth = (rqstSearchDt.getMonth()+1).toString();
# 				var yearDay = rqstSearchDt.getDate().toString();
# 				if(yearMonth < 10){
# 					yearMonth = "0"+yearMonth;
# 				}
# 				if(yearDay < 10){
# 					yearDay = "0"+yearDay;
# 				}
# 				var toDay3 = yearYear+"-"+yearMonth+"-"+yearDay;
# 				$("#rqstStDt").val(toDay3);
#
# 			}else if(dateTypeValue == 2){
#
# 				var rqstSearch2 = rqstSearchDt.getTime() - (7*24*60*60*1000);  //1주일
# 				rqstSearchDt.setTime(rqstSearch2);
# 				var rqstSearch2Year = rqstSearchDt.getFullYear().toString();
# 				var rqstSearch2Month = (rqstSearchDt.getMonth()+1).toString();
# 				var rqstSearch2Day = rqstSearchDt.getDate().toString();
#
# 				if(rqstSearch2Month < 10){
# 					rqstSearch2Month = "0"+rqstSearch2Month;
# 				}
# 				if(rqstSearch2Day < 10){
# 					rqstSearch2Day = "0"+rqstSearch2Day;
# 				}
# 				var rqst2Day = rqstSearch2Year+"-"+rqstSearch2Month+"-"+rqstSearch2Day;
# 				$("#rqstStDt").val(rqst2Day);
#
# 			}else if(dateTypeValue == 3){
#
# 				var rqstSearch3 = rqstSearchDt.getTime() - (30*24*60*60*1000); //1개월
# 				rqstSearchDt.setTime(rqstSearch3);
# 				var rqstSearch3Year = rqstSearchDt.getFullYear().toString();
# 				var rqstSearch3Month = (rqstSearchDt.getMonth()+1).toString();
# 				var rqstSearch3Day = rqstSearchDt.getDate().toString();
#
# 				if(rqstSearch3Month < 10){
# 					rqstSearch3Month = "0"+rqstSearch3Month;
# 				}
# 				if(rqstSearch3Day < 10){
# 					rqstSearch3Day = "0"+rqstSearch3Day;
# 				}
# 				var rqst3Day = rqstSearch3Year+"-"+rqstSearch3Month+"-"+rqstSearch3Day;
# 				$("#rqstStDt").val(rqst3Day);
#
# 			}else if(dateTypeValue == 4){
#
# 				var rqstSearch4 = rqstSearchDt.getTime() - (90*24*60*60*1000); //3개월
# 				rqstSearchDt.setTime(rqstSearch4);
# 				var rqstSearch4Year = rqstSearchDt.getFullYear().toString();
# 				var rqstSearch4Month = (rqstSearchDt.getMonth()+1).toString();
# 				var rqstSearch4Day = rqstSearchDt.getDate().toString();
#
# 				if(rqstSearch4Month < 10){
# 					rqstSearch4Month = "0"+rqstSearch4Month;
# 				}
# 				if(rqstSearch4Day < 10){
# 					rqstSearch4Day = "0"+rqstSearch4Day;
# 				}
# 				var rqst4Day = rqstSearch4Year+"-"+rqstSearch4Month+"-"+rqstSearch4Day;
# 				$("#rqstStDt").val(rqst4Day);
#
# 			}else if(dateTypeValue == 5){
#
# 				var rqstSearch5 = rqstSearchDt.getTime() - (180*24*60*60*1000); //6개월
# 				rqstSearchDt.setTime(rqstSearch5);
# 				var rqstSearch5Year = rqstSearchDt.getFullYear().toString();
# 				var rqstSearch5Month = (rqstSearchDt.getMonth()+1).toString();
# 				var rqstSearch5Day = rqstSearchDt.getDate().toString();
#
# 				if(rqstSearch5Month < 10){
# 					rqstSearch5Month = "0"+rqstSearch5Month;
# 				}
# 				if(rqstSearch5Day < 10){
# 					rqstSearch5Day = "0"+rqstSearch5Day;
# 				}
# 				var rqst5Day = rqstSearch5Year+"-"+rqstSearch5Month+"-"+rqstSearch5Day;
# 				$("#rqstStDt").val(rqst5Day);
#
# 			}else if(dateTypeValue == 6){
#
# 				var rqstSearch6 = rqstSearchDt.getTime() - (365*24*60*60*1000); //1년
# 				rqstSearchDt.setTime(rqstSearch6);
# 				var rqstSearch6Year = rqstSearchDt.getFullYear().toString();
# 				var rqstSearch6Month = (rqstSearchDt.getMonth()+1).toString();
# 				var rqstSearch6Day = rqstSearchDt.getDate().toString();
#
# 				if(rqstSearch6Month < 10){
# 					rqstSearch6Month = "0"+rqstSearch6Month;
# 				}
# 				if(rqstSearch6Day < 10){
# 					rqstSearch6Day = "0"+rqstSearch6Day;
# 				}
# 				var rqst6Day = rqstSearch6Year+"-"+rqstSearch6Month+"-"+rqstSearch6Day;
# 				$("#rqstStDt").val(rqst6Day);
# 			}
# 		}
#
# 		function validDateRange(sDateVal, eDateVal, numMonth){
# 	         var startMonth = parseInt(sDateVal.substring(5,7),  10) -1;
# 	         var startDay   = parseInt(sDateVal.substring(8,10), 10);
# 	         var endMonth   = parseInt(eDateVal.substring(5,7),  10) -1;
# 	         var endDay     = parseInt(eDateVal.substring(8,10), 10);
#
# 	         var objDateS = new Date(sDateVal.substring(0,4), startMonth, startDay);
# 	         var objDateE = new Date(eDateVal.substring(0,4), endMonth,   endDay);
#
# 	         return checkTermDate(objDateS, objDateE, numMonth);
# 	     }
#
# 		// 검색버튼 클릭 시
# 		function fn_searchList(){
#
# 			var rangeDate = 186;
# 			var rqstStDt = $('#rqstStDt').val().trim();
# 			var rqstEndDt = $('#rqstEndDt').val().trim();
#
# 			if(!rqstStDt || !rqstEndDt){
# 				jAlert("날짜를 입력하십시오.");
# 				$('#rqstStDt').focus();
# 				return;
# 			}
#
# 			var pattern = /[0-9]{4}-[0-9]{2}-[0-9]{2}/;
# 			if(!pattern.test(rqstStDt)||!pattern.test(rqstEndDt)){
# 				jAlert("올바른 날짜 형식(yyyymmdd 또는 yyyy-MM-dd)으로 입력하십시오.");
# 				return false;
# 			}
#
# 			var t1 = rqstStDt.split("-");
# 			var t2 = rqstEndDt.split("-");
# 			var startDate = new Date(t1[0],t1[1],t1[2]);
# 			var endDate = new Date(t2[0],t2[1],t2[2]);
# 			var diff = endDate - startDate;
# 			var currDay = 24 * 60 * 60 * 1000;
#
#
# 			if(parseInt(diff/currDay) > rangeDate){
# 				jAlert('기간은 6개월을 초과할 수 없습니다.');
# 				return;
# 			}
#
# 			//화면로딩중 추가 20200618-노경용
# 			$('.loading_submit').show();
#
# 			$('#pageIndex').val("1");
# 			var action = "/frmSub/pttn/openPttnList.npaid";
# 			var form = $("form#frm");
# 			/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 			$('.frmInfo').remove();
# 			$.each($("form#frmMngInfoVO").serializeArray(),function(key,val){
# 				var input = '<input class="frmInfo" type="hidden" name="'+val['name']+'" value="'+val['value']+'">';
# 				form.append(input);
# 			});
# 			form.attr("action", action).submit();
# 		}
#
# 		//프레임 공개민원 페이지 이동 20200604-노경용
# 		function frmPageSearch(){
# 			var action = "/frmSub/pttn/openPttnList.npaid";
# 			var form = $("form#frm");
# 			$('.frmInfo').remove();
# 			/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 			$.each($("form#frmMngInfoVO").serializeArray(),function(key,val){
# 				var input = '<input class="frmInfo" type="hidden" name="'+val['name']+'" value="'+val['value']+'">';
# 				form.append(input);
# 			});
# 			form.attr("action", action).submit();
# 		}
#
# 		// 제목 클릭 시
# 		function fn_detail(no,type){
#
# 			//화면로딩중 추가 20200618-노경용
# 			$('.loading_submit').show();
#
# 			$('#pttnRqstNo').val(no);
# 			$('#instPrcsSttsCd').val(type);
#
# 			var action = "/frmSub/pttn/openPttnListView.npaid";
# 			var form = $("form#frm");
# 			/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 			$('.frmInfo').remove();
# 			$.each($("form#frmMngInfoVO").serializeArray(),function(key,val){
# 				var input = '<input class="frmInfo" type="hidden" name="'+val['name']+'" value="'+val['value']+'">';
# 				form.append(input);
# 			});
# 			form.attr("action", action).submit();
# 		}
#
#
# 		//프레임 민원신청 페이지로 이동
# 		function fn_movePttnRqst() {
# 			if ($.chkEmptyVal(frm_frmMenuMngNo)) {  //프레임
# 				//화면로딩중 추가 20200618-노경용
# 				$('.loading_submit').show();
# 				var clsfRpsnNm = $('#bestInstPttnClsfCd option:selected').text();
# 				var PttnClsfCd = $('#bestInstPttnClsfCd option:selected').val();
# 				/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 				var action = "/frmSub/pttn/pttnRqstInfo.npaid";  //신청 페이지로
# 				var form = $("form#frm");
# 				$('.frmInfo').remove();
# 				$.each($("form#frmMngInfoVO").serializeArray(),function(key,val){
# 					var input = '<input class="frmInfo" type="hidden" name="'+val['name']+'" value="'+val['value']+'">';
# 					form.append(input);
# 				});
# 				form.attr("action", action).submit();
# 			}
# 		}
#
# 	</script>
# <header class="share" id="subTit" style="display:none;">
# <h3 id="h3_title">공개민원</h3>
# </header>
# <article id="txt">
# <form action="" id="frmMngInfoVO" method="post" name="frmMngInfoVO">
# <!-- 20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 -->
# <input id="frm_frmMenuMngNo" name="frm_frmMenuMngNo" type="hidden" value="WBF-1703-000232"/>
# <input id="frm_instCd" name="frm_instCd" type="hidden" value=""/>
# <input id="frm_clsfAplcYn" name="frm_clsfAplcYn" type="hidden" value=""/>
# <input id="frm_rcptPathInstCd" name="frm_rcptPathInstCd" type="hidden" value=""/>
# <input id="frm_frmUrlSn" name="frm_frmUrlSn" type="hidden" value=""/>
# <input id="frm_frmAllUrl" name="frm_frmAllUrl" type="hidden" value=""/>
# <input id="frm_prcsInstChcePsblYn" name="frm_prcsInstChcePsblYn" type="hidden" value=""/>
# <input id="frm_thptInfofAgreYn" name="frm_thptInfofAgreYn" type="hidden" value=""/>
# <input id="frmDsgnType" name="frmDsgnType" type="hidden" value=""/>
# <input id="frm_frmMenuClsfCd" name="frm_frmMenuClsfCd" type="hidden" value=""/>
# <input id="frm_chrgDeptCd" name="frm_chrgDeptCd" type="hidden" value=""/>
# <input id="frm_pttnDrctRcptYn" name="frm_pttnDrctRcptYn" type="hidden" value=""/>
# <input id="frm_rcptTySctnCd" name="frm_rcptTySctnCd" type="hidden" value=""/>
# <input id="frm_clsfRpsnNm" name="frm_clsfRpsnNm" type="hidden" value=""/>
# <input id="frm_frmMngrCnt" name="frm_frmMngrCnt" type="hidden" value=""/>
# <input id="frm_sysCrtnMngrIdCnt" name="frm_sysCrtnMngrIdCnt" type="hidden" value=""/>
# <input id="frm_areaSntlYn" name="frm_areaSntlYn" type="hidden" value=""/>
# <input id="frm_atchFileSntlYn" name="frm_atchFileSntlYn" type="hidden" value=""/>
# <input id="frm_drqstrInfoIndcYn" name="frm_drqstrInfoIndcYn" type="hidden" value=""/>
# <input id="frm_dpttnrInfoSntlYn" name="frm_dpttnrInfoSntlYn" type="hidden" value=""/>
# <input id="frm_pttnSctnCd" name="frm_pttnSctnCd" type="hidden" value=""/>
# <input id="frm_scryPttnSctnCd" name="frm_scryPttnSctnCd" type="hidden" value=""/>
# <input id="frm_gdncWrdsUseYn" name="frm_gdncWrdsUseYn" type="hidden" value=""/>
# <input id="frm_egppYn" name="frm_egppYn" type="hidden" value=""/>
# <input id="frm_cnrsYn" name="frm_cnrsYn" type="hidden" value=""/>
# <input id="frm_addnCltnItmUseYn" name="frm_addnCltnItmUseYn" type="hidden" value=""/>
# <input id="frm_pttnClsfCd" name="frm_pttnClsfCd" type="hidden" value=""/>
# <input id="frm_prcsTmltNumd" name="frm_prcsTmltNumd" type="hidden" value=""/>
# <input id="frm_basePrcsPrd" name="frm_basePrcsPrd" type="hidden" value=""/>
# <input id="frm_menuCd" name="frm_menuCd" type="hidden" value=""/>
# <input id="frm_proPotMngrIdCnt" name="frm_proPotMngrIdCnt" type="hidden" value=""/>
# <input id="frm_ablYn" name="frm_ablYn" type="hidden" value=""/>
# <input id="acesMode" name="acesMode" type="hidden" value=""/>
# <input id="frm_lwsInstNm" name="frm_lwsInstNm" type="hidden" value=""/>
# <input id="frm_pttnPrcsCaseYn" name="frm_pttnPrcsCaseYn" type="hidden" value=""/>
# <input id="frm_cntnCl" name="frm_cntnCl" type="hidden" value=""/>
# </form>
# <!-- 게시글 검색 : s -->
# <form action="" id="frm" method="post" name="frm">
# <input name="_csrf" type="hidden" value="ba995069-83ae-4d88-a646-c8036085dac3">
# <input id="recordCountPerPage" name="recordCountPerPage" type="hidden" value="10">
# <input id="pageIndex" name="pageIndex" type="hidden" value="1">
# <input id="epUnionSn" name="epUnionSn" type="hidden" value=""/>
# <input id="pttnRqstNo" name="pttnRqstNo" type="hidden" value=""/>
# <input id="instPrcsSttsCd" name="instPrcsSttsCd" type="hidden" value=""/>
# <input id="dutySctnNm" name="dutySctnNm" type="hidden" value=""/>
# <input id="lcgovBlngInstCd" name="lcgovBlngInstCd" type="hidden" value=""/>
# <div class="prog_search">
# <div class="boardSch">
# <div class="bSch_row" id="div_bestInstPttnClsfCd" style="display:none;">
# <div class="bSch_col full">
# <div class="label">
# <label for="bestInstPttnClsfCd">신청분야</label>
# </div>
# <div class="w45p">
# <select id="bestInstPttnClsfCd" name="bestInstPttnClsfCd">
# <option selected="selected" value="all">전체</option>
# </select>
# </div>
# </div>
# </div>
# <div class="bSch_row">
# <div class="bSch_col full">
# <div class="label">
# <label for="searchWordType">검색어</label>
# </div>
# <div class="sch_def">
# <select id="searchWordType" name="searchWordType">
# <option value="1">제목</option>
# <option value="2">요지</option>
# </select>
# <input id="searchWord" name="searchWord" title="검색어를 입력하세요" type="text" value=""/>
# </div>
# </div>
# </div>
# <div class="bSch_row">
# <div class="bSch_col full">
# <div class="label">
# <label for="rqstStDt">기간</label>
# </div>
# <div class="dateWrap type_1">
# <input class="datepicker" id="rqstStDt" name="rqstStDt" title="시작일을 입력하세요. 예)2020-01-01" type="text" value="2020-05-01">
# 								~
# 								<input class="datepicker" id="rqstEndDt" name="rqstEndDt" title="종료일을 입력하세요. 예)2020-01-01" type="text" value="2020-06-15">
# <select class="datesel" id="dateType" name="dateType" onchange="javascript:rqstDateSelect();" title="기간을 선택하세요">
# <option value="0">선택</option>
# <option value="2">1주일</option>
# <option value="3">1개월</option>
# <option value="4">3개월</option>
# <option value="5">6개월</option>
# <!-- 									<option value="6">1년</option> -->
# </select>
# </input></input></div>
# </div>
# </div>
# <div class="bSch_btn">
# <button class="btn black" onclick="javaScript:fn_searchList();" type="button">검색</button>
# <button class="btn white" type="reset">초기화</button>
# </div>
# </div>
# </div>
# <!-- 게시글 검색 : e -->
# <!-- 게시판 상단 정보 : s -->
# <div class="prog_util">
# <span class="total">총 <span>37</span>건 등록 (1/4)</span>
# <div class="align">
# <strong class="hide">게시판 아이콘 설명</strong>
# <ul class="b_iconType">
# </ul>
# <label class="hide" for="listCnt">글목록 개수 지정</label>
# <select id="listCnt" onchange="chngCountForPage('post',this.value)">
# <option selected="selected" value="10">10개씩</option>
# <option value="20">20개씩</option>
# <option value="30">30개씩</option>
# <option value="40">40개씩</option>
# <option value="50">50개씩</option>
# </select>
# <input id="focusPerPageYn" name="focusPerPageYn" type="hidden" value="">
# </input></div>
# </div>
# <!-- 게시판 상단 정보 : e -->
# <!-- 민원사례 게시판 : s -->
# <table class="tbl default brd1">
# <caption>
# <strong>공개민원 목록</strong>
# <details>
# <summary>공개민원 목록 게시판으로, 번호, 제목, 처리기관, 등록일로 구분되어 있습니다.</summary>
# </details>
# </caption>
# <colgroup>
# <col style="width:70px"/>
# <col style="width:auto"/>
# <col style="width:150px"/>
# <col style="width:150px"/>
# <col style="width:70px"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">번호</th>
# <th scope="col">제목</th>
# <th scope="col">담당부서</th>
# <th scope="col">등록일</th>
# <th scope="col">처리상태</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>37</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0054656','00620090');">쾌적한 유등천을 만듭시다</a></td>
# <td>하천관리사업소</td>
# <td>2020.05.03</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>36</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0090030','00620090');">가양동 제2시립 도서관 환영 그런데...</a></td>
# <td>문화예술정책과</td>
# <td>2020.05.05</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>35</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0094534','00620090');">코로나로 인한 임대료 감면을 한 임대사업자에 대한 지원 안내 요청</a></td>
# <td>세정과</td>
# <td>2020.05.05</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>34</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0145809','00620090');">배차시간 미준수</a></td>
# <td>버스운영과</td>
# <td>2020.05.07</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>33</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0148938','00620090');">대전 시내버스 1002번 일정 시간 준수 운행 요청</a></td>
# <td>버스운영과</td>
# <td>2020.05.07</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>32</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0194283','00620090');">대전시 재난 지원금에 대해</a></td>
# <td>복지정책과</td>
# <td>2020.05.08</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>31</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0206151','00620090');">대전시 재난지원금 지급에 있어서의 터무니없는 1인가구 차별행위를 시정바랍니다.</a></td>
# <td>복지정책과</td>
# <td>2020.05.09</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>30</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0269715','00620090');">대전시 거주하는 젊은이들이 서울 출정 클럽 파티 문화 확인!!!</a></td>
# <td>위생안전과</td>
# <td>2020.05.12</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>29</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0322485','00620090');">버스 마스크 미착용 벌금부여부탁드립니다</a></td>
# <td>버스운영과</td>
# <td>2020.05.13</td>
# <td>완료</td>
# </tr>
# <tr>
# <td>28</td>
# <td class="left"><a class="tit" href="javaScript:void(0);" onclick="javaScript:fn_detail('1AA-2005-0322836','00620090');">대전역에서 대기하고 있는 택시는 멀리 가는 사람만 이용할 수 있나요?</a></td>
# <td>운송주차과</td>
# <td>2020.05.13</td>
# <td>완료</td>
# </tr>
# </tbody>
# </table>
# <!-- 민원사례 게시판 : e -->
# <div class="page_list">
# <ul class="pagination" style="position:relative;">
# <span class="nep_p_prev"><a href="?pageIndex=1" onclick="frmPageLink(1);return false; "><span class="hide">이전 페이지로 이동</span></a></span>
# <strong class="ds_number"><a onclick="return false;">1</a></strong>
# <a class="ds_number" href="?pageIndex=2" onclick="frmPageLink(2);return false; ">2</a>
# <a class="ds_number" href="?pageIndex=3" onclick="frmPageLink(3);return false; ">3</a>
# <a class="ds_number" href="?pageIndex=4" onclick="frmPageLink(4);return false; ">4</a>
# <span class="paging_count">1/4</span><span class="nep_p_next"><a href="?pageIndex=2" onclick="frmPageLink(2);return false; "><span class="hide">다음 페이지 묶음으로 이동</span></a></span>
# </ul>
# </div>
# </input></input></input></form>
# <div class="btnArea right" id="div_btnPttnRqst">
# <button class="btn gray" id="btnPttnRqst" onclick="fn_movePttnRqst();" type="button"><span>신청</span></button>
# </div>
# </article>
# <!-- 로딩 화면 추가 20200618-노경용 -->
# <div class="loading_submit" style="display:none;">
# <div class="apload_ing"></div>
# <div class="load_box">
# <span><img alt="로딩 중" src="/resource/images/paid/biz/content/load_ing.png"/></span>
# <strong>화면 로딩 중</strong>
# <p>요청하신 화면을 로딩 중입니다. 잠시만 기다려주십시오.</p>
# </div>
# </div>
# <script src="/resource/js/paid/cmmn/pagination.js" type="text/javascript"></script>
# <div id="allMenu"></div>
# </section>
# </div>
# </main>
# </div>
# <!-- 1 : 개인정보 스크립트 -->
# <script src="/resource/app/applex_wdigm_html5/applex_local.js" type="text/javascript"></script>
# <!-- 2 : 첨부파일 변환 스크립트 -->
# <iframe class="uploadIFrame1" id="uploadIFrame1" name="uploadIFrame1" style="display: none; visibility: hidden;" title="첨부파일 변환"></iframe>
# <!-- 3 : 개인정보 차단 스크립트 -->
# <!-- 4 : onchang 함수 -->
# <!-- 5 : 첨부파일 변환 알림 문구 -->
# <!-- <div id="applex_wdigm_html5_waiting"></div> -->
# </body>
# </html>

# %%
sub_url='https://www.epeople.go.kr/frmSub/pttn/openPttnListView.npaid'

# %%
sub_data={
'instPrcsSttsCd': '00620090',
'pttnRqstNo': '1AA-2005-0054656'
}

# %%
sub_header={
    'Cookie': '_xm_webid_1_=160914436; JSESSIONID=RYIG9IxfTivU+mlZ0rhzlAyI.euser34; SL_GWPT_Show_Hide_tmp=1; SL_wptGlobTipTmp=1'#*
}

# %%
sub_page=requests.post(sub_url,data=sub_data,headers=sub_header)

# %%
sub_soup=BeautifulSoup(sub_page.content,'html.parser')

# %%
sub_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="_csrf" name="_csrf_parameter"><meta content="X-CSRF-TOKEN" name="_csrf_header"><meta content="ba995069-83ae-4d88-a646-c8036085dac3" name="_csrf">
# <title>국민신문고</title>
# <link href="/resource/css/paid/nep/pot/css.css?t_=20200618_1639" rel="stylesheet" type="text/css"/>
# <link href="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css"/>
# <link href="/resource/css/paid/cmmn/jAlert.css" rel="stylesheet" type="text/css"/>
# <script src="/resource/js/paid/cmmn/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.cookie.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/bootstrap.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/loading.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/sendAjaxReq.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.form.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.concat.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/pgwslideshow/pgwslideshow.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/pot/common.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.money.plus.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alphanumeric.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alerts.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/validation.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.file.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.popup.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/cmmn/common.sch.js?t_=20200618_1639" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/pot/kakao.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var contexts = '';
# var JBOSS_NODE_NAME = 'euser34';
#
# var acesMode = 'frm';  //프레임 접근 구분자
# $(function(){
# 	if (acesMode == 'frm') {
# 		$('#contentWrap').addClass('full');  //프레임일 경우 화면 레이아웃 Full
# 	}
# });
#
#
# Kakao.init('53056da5f179f887698576ec42f7468a');
#
# function fn_kakaoLink(title, pageUrl) {
# 	title = "국민신문고 | " + title;
#
#     Kakao.Link.sendDefault({
#       objectType: 'text',
#       text: title,
#       link: {
#         mobileWebUrl: pageUrl,
#         webUrl: pageUrl
#       },
#       buttons: [
#         {
#           title: '웹으로 이동',
#           link: {
#             mobileWebUrl: pageUrl,
#             webUrl: pageUrl
#           }
#         }
#       ]
#     });
#
# }
# </script>
# </meta></meta></meta></head>
# <body>
# <div class="loading black" style="position:fixed; width:100%; height:auto; min-height:100%; z-index:100; top:0; left:0; display:block; opacity:.6;">
# <div style="width:100%; height:100%; top:50%; left:50%; position:absolute;">
# <span style="display:table-cell; text-align:center; vertical-align:middle;">
# <img alt="로딩이미지" src="/resource/images/paid/cmmn/bg_progress.gif"/>
# </span>
# </div>
# </div>
# <div id="wrap">
# <!-- 세션에 접근 시스템 구분자가 프레임이 아닐 경우(프레임 통합 메뉴로 접근시 세션에 접근 시스템 구분자를 추가)만 헤더와 푸터를 포함하도록 처리 -->
# <div id="containerAcc"></div>
# <main id="container">
# <div class="layout">
# <section id="contentWrap">
# <script src="/resource/js/paid/cmmn/common.file.js" type="text/javascript"></script>
# <script>
#
# 		//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 시작
# 		var frm_frmMenuMngNo = '';  //프레임메뉴관리번호
# 		var frm_frmUrlSn = '';  //프레임 일련번호
# 		var frm_frmAllUrl = '';  //프레임 전체 URL
# 		//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 끝
# 		$(function(){
# 			//20191118/통합연계 김정원/프레임통합메뉴 관련 스크립트 추가 시작
# 			if ($.chkEmptyVal(frm_frmMenuMngNo)) {  //세션에 프레임메뉴관리번호가 존재하면 프레임통합메뉴로 인증 후 접근한 것
# 				if (frm_frmUrlSn == '3' || frm_frmAllUrl.indexOf('openPttnList.npaid') > -1) {  //공개민원
# 					$('#h3_title').text('공개민원 유사사례');
# 				} else if (frm_frmUrlSn == '18' || frm_frmAllUrl.indexOf('pttnPolicyQnaList.npaid') > -1) {  //민원·정책Q&A
# 					$('#h3_title').text('민원·정책 유사사례');
# 				} else if (frm_frmUrlSn == '19' || frm_frmAllUrl.indexOf('pttnQnaList.npaid') > -1) {  //민원Q&A
# 					$('#h3_title').text('민원 유사사례');
# 				} else if (frm_frmUrlSn == '20' || frm_frmAllUrl.indexOf('policyQnaList.npaid') > -1) {  //정책Q&A
# 					$('#h3_title').text('정책 유사사례');
# 				}
# 			}
# 			//20191118/통합연계 김정원/프레임통합메뉴 관련 스크립트 추가 끝
# 		});
#
#
# 		//파일 다운로드 버튼 클릭시
# 		function fn_fileDownload(fileId, fileGrpId){
# 			var param = {
# 				atchFileId : fileId,
# 				atchFileGrpId : fileGrpId
# 			}
# 			gfn_downForm("download", param, "/paid/syscmmn/fileDwld.npaid");
# 		}
#
# 		// 만족도 점수(라디오버튼) 클릭
# 		function fn_checkSrc(score){
# 			$('#stsfdEvlGrdScre').val(score);
# 		}
#
# 		// 만족도 등록버튼 클릭
# 		function fn_frmSubmit(){
# 			var dutySctnNm = $('#dutySctnNm').val();
# 			if(dutySctnNm == "tqapttn"){
# 				$('#pttnPlcySctnCd').val("0C030001");
# 			} else if(dutySctnNm == "tqaplcy"){
# 				$('#pttnPlcySctnCd').val("0C030002");
# 			}
#
# 			var options = $.sendAjaxSumit.setOptions(submitSuccessHandler);
# 			document.frm.action="/nep/pttn/gnrlPttn/insertPttnPlcyQnaStsfd.npaid";
# 			$.sendAjaxSumit.start($("#frm"), options);
#
# 			function submitSuccessHandler(result) {
# 				var re = JSON.parse(result);
# 				if (re.success) {
# 					jAlert("만족도 평가에 참여해 주셔서 감사합니다.",function(){
# 						document.frm.action="/nep/pttn/gnrlPttn/pttnSmlrCaseDetail.npaid";
# 						document.frm.submit();
# 					});
# 				} else {
# 					document.frm.action="/nep/pttn/gnrlPttn/pttnSmlrCaseDetail.npaid";
# 				}
# 			}
# 			document.frm.action="/nep/pttn/gnrlPttn/pttnSmlrCaseDetail.npaid";
# 		}
#
# 		// 목록버튼 클릭
# 		function fn_returnToList(){
# 			/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 			var action = "/frmSub/pttn/openPttnList.npaid";
# 			var form = $("form#frm");
# 			$.each($("form#frmMngInfoVO").serializeArray(),function(key,val){
# 				var input = '<input type="hidden" name="'+val['name']+'" value="'+val['value']+'">';
# 				form.append(input);
# 			});
# 			form.attr("action", action).submit();
# 		}
# 	</script>
# <header class="share" id="subTit" style="display:none;">
# <h3 id="h3_title">민원 질의응답·답변원문</h3>
# </header>
# <article id="txt">
# <div class="same_mwWrap">
# <div class="samBox mw">
# <strong class="sam_tit"><span>사례</span></strong>
# <div class="sam_cont">
# <div class="samC_top">
# <strong></strong>
# </div>
# <div class="samC_c">
#
# 						코로나19로 노고가 많으십니다.
# <br/>수 년간 하천 미정비로 유등천이 흐르는 수침교 다리 인근은 폭우로 물이 불어 날때마다 상류에서 떠내려온 건설자재 폐기물(흄관 등)과 자꾸만 쌓여가는 돌더미 흙으로 물의 유속이 늦어지고 그것들을 오랜기간 방치하다 보니 하천 가운데에 섬처럼 돌과 흙이 쌓이고 그위로 나무까지 자라 흉물스럽고 각종 폐기물로 인해 모기, 파리, 하루살이 등 각종 해충이 늘어나 주민들의 원성이 되고 있으며 요즘처럼 점점 더워지는 계절이 오면 유등천을 끼고 있는 아파트는 모기 등 각종 해충으로 인한 또다른 새로운 바이러스가 발생 되는거 아닌지 걱정 됩니다.
# <br/>하천 평탄작업등 유등천 정비로 잔잔한 물흐름을 유지시키고 각종폐기물과 하천 중간의 나무제거 및 풀제거로 쾌적한 유등천이 됐으면 하는 바램 입니다.
# <br/>수고하세요.
# 					</div>
# <span class="samC_date"></span>
# </div>
# </div>
# <div class="btnArea right">
# <button class="btn fill" onclick="javaScript:fn_returnToList();" type="button">목록</button>
# </div>
# </div>
# <form action="" id="frmMngInfoVO" method="post" name="frmMngInfoVO">
# <!-- 20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 -->
# <input id="frm_frmMenuMngNo" name="frm_frmMenuMngNo" type="hidden" value=""/>
# <input id="frm_instCd" name="frm_instCd" type="hidden" value=""/>
# <input id="frm_clsfAplcYn" name="frm_clsfAplcYn" type="hidden" value=""/>
# <input id="frm_rcptPathInstCd" name="frm_rcptPathInstCd" type="hidden" value=""/>
# <input id="frm_frmUrlSn" name="frm_frmUrlSn" type="hidden" value=""/>
# <input id="frm_frmAllUrl" name="frm_frmAllUrl" type="hidden" value=""/>
# <input id="frm_prcsInstChcePsblYn" name="frm_prcsInstChcePsblYn" type="hidden" value=""/>
# <input id="frm_thptInfofAgreYn" name="frm_thptInfofAgreYn" type="hidden" value=""/>
# <input id="frmDsgnType" name="frmDsgnType" type="hidden" value=""/>
# <input id="frm_frmMenuClsfCd" name="frm_frmMenuClsfCd" type="hidden" value=""/>
# <input id="frm_chrgDeptCd" name="frm_chrgDeptCd" type="hidden" value=""/>
# <input id="frm_pttnDrctRcptYn" name="frm_pttnDrctRcptYn" type="hidden" value=""/>
# <input id="frm_rcptTySctnCd" name="frm_rcptTySctnCd" type="hidden" value=""/>
# <input id="frm_clsfRpsnNm" name="frm_clsfRpsnNm" type="hidden" value=""/>
# <input id="frm_frmMngrCnt" name="frm_frmMngrCnt" type="hidden" value=""/>
# <input id="frm_sysCrtnMngrIdCnt" name="frm_sysCrtnMngrIdCnt" type="hidden" value=""/>
# <input id="frm_areaSntlYn" name="frm_areaSntlYn" type="hidden" value=""/>
# <input id="frm_atchFileSntlYn" name="frm_atchFileSntlYn" type="hidden" value=""/>
# <input id="frm_drqstrInfoIndcYn" name="frm_drqstrInfoIndcYn" type="hidden" value=""/>
# <input id="frm_dpttnrInfoSntlYn" name="frm_dpttnrInfoSntlYn" type="hidden" value=""/>
# <input id="frm_pttnSctnCd" name="frm_pttnSctnCd" type="hidden" value=""/>
# <input id="frm_scryPttnSctnCd" name="frm_scryPttnSctnCd" type="hidden" value=""/>
# <input id="frm_gdncWrdsUseYn" name="frm_gdncWrdsUseYn" type="hidden" value=""/>
# <input id="frm_egppYn" name="frm_egppYn" type="hidden" value=""/>
# <input id="frm_cnrsYn" name="frm_cnrsYn" type="hidden" value=""/>
# <input id="frm_addnCltnItmUseYn" name="frm_addnCltnItmUseYn" type="hidden" value=""/>
# <input id="frm_pttnClsfCd" name="frm_pttnClsfCd" type="hidden" value=""/>
# <input id="frm_prcsTmltNumd" name="frm_prcsTmltNumd" type="hidden" value=""/>
# <input id="frm_basePrcsPrd" name="frm_basePrcsPrd" type="hidden" value=""/>
# <input id="frm_menuCd" name="frm_menuCd" type="hidden" value=""/>
# <input id="frm_proPotMngrIdCnt" name="frm_proPotMngrIdCnt" type="hidden" value=""/>
# <input id="frm_ablYn" name="frm_ablYn" type="hidden" value=""/>
# <input id="acesMode" name="acesMode" type="hidden" value=""/>
# <input id="frm_lwsInstNm" name="frm_lwsInstNm" type="hidden" value=""/>
# <input id="frm_pttnPrcsCaseYn" name="frm_pttnPrcsCaseYn" type="hidden" value=""/>
# <input id="frm_cntnCl" name="frm_cntnCl" type="hidden" value=""/>
# </form>
# <form action="" id="frm" method="post" name="frm">
# <input name="_csrf" type="hidden" value="ba995069-83ae-4d88-a646-c8036085dac3">
# <input id="epUnionSn" name="epUnionSn" type="hidden" value="1AA-2005-0054656"/>
# <input id="dutySctnNm" name="dutySctnNm" type="hidden" value=""/>
# <input id="bestInstPttnClsfCd" name="bestInstPttnClsfCd" type="hidden" value=""/>
# <input id="rcptInstMenuCd" name="rcptInstMenuCd" type="hidden" value=""/>
# <input id="instCd" name="instCd" type="hidden" value=""/>
# <input id="stsfdEvlGrdScre" name="stsfdEvlGrdScre" type="hidden" value="5"/>
# <input id="pttnPlcySctnCd" name="pttnPlcySctnCd" type="hidden" value=""/>
# <input id="deptCd" name="deptCd" type="hidden" value=""/>
# <!-- 이하 검색조건 유지용 -->
# <input id="pageIndex" name="pageIndex" type="hidden" value="1">
# <input id="searchWordType" name="searchWordType" type="hidden" value="">
# <input id="searchWord" name="searchWord" type="hidden" value="">
# <input id="rqstStDt" name="rqstStDt" type="hidden" value="">
# <input id="rqstEndDt" name="rqstEndDt" type="hidden" value="">
# <input id="pttnTypeNm" name="pttnTypeNm" type="hidden" value="">
# <input id="searchInstType" name="searchInstType" type="hidden" value="">
# <input id="searchInstCd" name="searchInstCd" type="hidden" value="">
# </input></input></input></input></input></input></input></input></input></form>
# </article>
# <div id="allMenu"></div>
# </section>
# </div>
# </main>
# </div>
# <!-- 1 : 개인정보 스크립트 -->
# <script src="/resource/app/applex_wdigm_html5/applex_local.js" type="text/javascript"></script>
# <!-- 2 : 첨부파일 변환 스크립트 -->
# <iframe class="uploadIFrame1" id="uploadIFrame1" name="uploadIFrame1" style="display: none; visibility: hidden;" title="첨부파일 변환"></iframe>
# <!-- 3 : 개인정보 차단 스크립트 -->
# <!-- 4 : onchang 함수 -->
# <!-- 5 : 첨부파일 변환 알림 문구 -->
# <!-- <div id="applex_wdigm_html5_waiting"></div> -->
# </body>
# </html>
