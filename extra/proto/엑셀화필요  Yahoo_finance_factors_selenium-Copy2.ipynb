# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys

# %%
# 야후 파이낸스 오픈
chrome = webdriver.Chrome('chromedriver.exe')
driver = chrome.get("https://finance.yahoo.com/")
# 로그인
sign_btn = chrome.find_element_by_css_selector('#header-signin-link') 
sign_btn.click()
time.sleep(1)

# %%
# ID/PW 입력   
id_box = chrome.find_element_by_css_selector('#login-username')
id_box.send_keys("richard@hoztec.com")
time.sleep(1)
id_box.send_keys(Keys.ENTER)
time.sleep(1)
psw_box = chrome.find_element_by_css_selector('#login-passwd')
psw_box.send_keys("click3801!")
time.sleep(1)
psw_box.send_keys(Keys.ENTER)

# %%
# 검색
input_box = chrome.find_element_by_css_selector('#yfin-usr-qry')
input_box.send_keys("005930.KS")
time.sleep(1)
input_box.send_keys(Keys.ENTER)

# %%
# finance 클릭
fnc_btn = chrome.find_element_by_css_selector('#quote-nav > ul > li:nth-child(7) > a')
fnc_btn.click()

# %%
# quarterly 클릭
qt_btn = chrome.find_element_by_css_selector('#Col1-1-Financials-Proxy > section > div.Mt\(18px\).Mb\(15px\) > div.Fl\(end\).smartphone_Fl\(n\).IbBox.smartphone_My\(10px\).smartphone_D\(b\) > button > div > span')
qt_btn.click()

# %%
# expand all 클릭
exp_btn = chrome.find_element_by_css_selector('#Col1-1-Financials-Proxy > section > div.Mb\(10px\) > button > div > span')
exp_btn.click()

# %%
# Balance_sheet 클릭
BS_btn = chrome.find_element_by_css_selector("#Col1-1-Financials-Proxy > section > div.Mt\(18px\).Mb\(15px\) > div:nth-child(1) > div > a:nth-child(2) > div > span")
BS_btn.click()

# %%
# quarterly 클릭
qt_btn = chrome.find_element_by_css_selector('#Col1-1-Financials-Proxy > section > div.Mt\(18px\).Mb\(15px\) > div.Fl\(end\).smartphone_Fl\(n\).IbBox.smartphone_My\(10px\).smartphone_D\(b\) > button > div > span')
qt_btn.click()

# %%
# CashFlow 클릭
CF_btn = chrome.find_element_by_css_selector("#Col1-1-Financials-Proxy > section > div.Mt\(18px\).Mb\(15px\) > div:nth-child(1) > div > a:nth-child(3) > div > span")
CF_btn.click()

# %%
# quarterly 클릭
qt_btn = chrome.find_element_by_css_selector('#Col1-1-Financials-Proxy > section > div.Mt\(18px\).Mb\(15px\) > div.Fl\(end\).smartphone_Fl\(n\).IbBox.smartphone_My\(10px\).smartphone_D\(b\) > button > div > span')
qt_btn.click()

# %%
import string

# %%
chart = chrome.find_element_by_css_selector("#Main")  #Col1-1-Financials-Proxy  
chart_data = chart.text

# %%
chart_data
# Out:
# 'Show:Income StatementBalance SheetCash Flow\nAnnualQuarterly\nDownload\nIncome Statement\nCollapse All\nAll numbers in thousands\nBreakdown\\nTotal Revenue\n230,400,881,000 59,884,760,000 62,003,471,000 56,127,104,000 52,385,546,000 59,265,050,000 65,459,993,000 58,482,658,000 60,563,714,000 65,978,412,000 62,048,901,000 61,000,537,000 50,547,526,000 53,331,740,000 47,815,633,000 50,937,120,000 49,782,252,000 53,315,453,000 51,682,572,000 48,537,539,000 47,117,918,000 52,730,122,000 47,447,310,000 52,353,229,000 53,675,326,000 59,276,625,000 59,083,499,000 57,464,448,000 52,868,095,000 56,058,847,000 52,177,270,000 
# ...

# %%
chart_splt = chart_data.split('\n')

# %%
gets={}
for x in range(0,len(chart_splt),2):
    gets[chart_splt[x]]=chart_splt[x+1]

# %%
df=pd.DataFrame(gets)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-a27dcd5bbc54> in <module>
# ----> 1 df=pd.DataFrame(gets)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
Brkdwn_data = gets["Breakdown"]
Brkdwn_data_splt = Brkdwn_data.split("\/")
Brkdwn_data_splt
# Out:
# ['']

# %%
nt_icm_data = gets["Net Income"]
nt_icm_data_splt = nt_icm_data.split("\/")
nt_icm_data_splt
# Out:
# ['21,505,054,000 5,227,995,000 6,105,039,000 5,064,530,000 5,107,490,000 8,330,069,000 12,967,428,000 10,981,547,000 11,611,833,000 12,016,324,000 11,039,771,000 10,799,942,000 7,488,532,000 6,917,181,000 4,408,790,000 5,826,178,000 5,263,506,000 3,242,467,000 5,306,104,000 5,626,734,000 4,519,323,000 5,285,891,000 4,135,422,000 6,176,506,000 7,484,680,000 7,219,744,000 8,049,537,000 7,575,016,000 6,976,918,000 6,850,567,000 6,424,872,000 5,049,042,000 4,860,894,000 4,262,309,481 3,300,157,000 3,456,956,000 2,714,645,000 3,299,525,359 4,310,375,000 4,172,692,000 4,016,443,000']

# %%
tt_rvn_data = gets["Total Revenue"]
tt_rvn_data_splt = tt_rvn_data.split("\/")
tt_rvn_data_splt
# Out:
# ['230,400,881,000 59,884,760,000 62,003,471,000 56,127,104,000 52,385,546,000 59,265,050,000 65,459,993,000 58,482,658,000 60,563,714,000 65,978,412,000 62,048,901,000 61,000,537,000 50,547,526,000 53,331,740,000 47,815,633,000 50,937,120,000 49,782,252,000 53,315,453,000 51,682,572,000 48,537,539,000 47,117,918,000 52,730,122,000 47,447,310,000 52,353,229,000 53,675,326,000 59,276,625,000 59,083,499,000 57,464,448,000 52,868,095,000 56,058,847,000 52,177,270,000 47,596,979,000 45,270,517,000 47,303,935,228 41,273,965,000 39,438,854,000 36,985,017,000 41,871,078,781 40,229,261,000 37,891,918,000 34,638,070,000']

# %%
nrmlz_ebitda_data = gets["Normalized EBITDA"]
nrmlz_ebitda_data_splt = nrmlz_ebitda_data.split("\/")
nrmlz_ebitda_data_splt
# Out:
# ['60,511,792,000 16,663,718,000 15,518,895,000 14,220,787,000 14,108,392,000 18,561,274,000 25,020,233,000 21,828,250,000 22,353,642,000 23,128,514,000 20,748,979,000 19,827,502,000 15,438,707,000 14,273,917,000 10,400,090,000 13,617,068,000 12,406,186,000 12,483,244,000 12,930,398,000 12,784,686,000 11,192,604,000 10,428,809,000 9,626,917,000 12,346,577,000 14,709,661,000 12,722,871,000 14,575,995,000 14,048,927,000 13,318,079,000 13,326,719,000 12,544,941,000 10,689,873,000 10,339,635,000 10,171,883,258 7,815,338,000 7,641,549,000 6,587,329,000 7,169,265,705 8,446,050,000 8,230,013,000 7,729,427,000']

# %%
sthdls_eqt_data = gets["Stockholders' Equity"]
sthdls_eqt_data_splt = sthdls_eqt_data.split("\/")
sthdls_eqt_data_splt
# Out:
# ['254,915,472,000 255,403,450,000 249,892,661,000 245,499,809,000 240,068,993,000 234,476,380,000 225,671,417,000 215,884,505,000 207,213,416,000 203,504,410,000 193,654,461,000 183,119,607,000 186,424,328,000 173,269,659,000 175,638,353,000 172,130,138,000 172,876,767,000 174,394,863,000 167,808,559,000 161,595,949,000 162,181,725,000 157,717,152,000 153,818,770,000 149,881,253,000 144,442,616,000 139,198,886,000 133,246,470,000 124,136,879,000 117,094,052,000 112,304,233,000 107,789,475,000 103,097,087,000 97,480,294,483 94,372,069,000 90,628,913,000 87,302,752,000 85,470,091,898']

# %%
tt_lbt_data = gets["Total Liabilities Net Minority Interest"]
tt_lbt_data_splt = tt_lbt_data.split("\/")
tt_lbt_data_splt
# Out:
# ['89,684,076,000 89,943,741,000 85,193,101,000 91,852,732,000 91,604,067,000 95,092,626,000 85,563,535,000 89,213,233,000 87,260,662,000 85,887,328,000 76,883,688,000 74,399,417,000 69,211,291,000 64,935,077,000 62,118,157,000 62,913,603,000 63,119,716,000 65,838,937,000 57,754,240,000 59,631,070,000 62,334,770,000 68,278,794,000 65,209,610,000 69,730,872,000 64,059,008,000 66,374,078,000 65,382,074,000 62,037,027,000 59,591,364,000 60,188,312,000 56,035,900,000 54,649,928,000 53,785,931,529 49,501,637,000 43,361,485,000 45,033,401,000 44,939,652,557']

# %%
cmn_stck_data = gets["Common Stock"]
cmn_stck_data_splt = cmn_stck_data.split("\/")
cmn_stck_data_splt
# Out:
# ['778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,000 778,047,468 778,047,000 778,047,000 778,047,000 778,047,328']

# %%
oprt_cf_data = gets["Operating Cash Flow"]
oprt_cf_data_splt = oprt_cf_data.split("\/")
oprt_cf_data_splt
# Out:
# ['45,382,915,000 19,717,140,000 13,826,599,000 6,594,865,000 5,244,311,000 22,428,080,000 15,549,657,000 13,437,774,000 15,616,352,000 21,691,546,000 17,447,062,000 12,426,162,000 10,597,271,000 10,985,912,000 14,336,597,000 13,344,845,000 8,718,290,000 12,356,351,000 11,873,815,000 10,709,603,000 5,121,992,000 5,405,589,000 10,442,348,000 8,914,556,000 12,212,896,000 10,275,299,000 15,014,197,000 8,598,595,000 12,819,349,000 12,074,303,000 11,539,742,000 5,931,820,000 8,426,944,000 7,305,216,994 6,686,653,000 4,567,596,000 4,343,711,000 7,517,122,182 6,757,339,000 3,820,275,000 5,226,417,000']

# %%
import pandas as pd
from pandas import DataFrame as pf
import numpy as np

# %%
df=pd.Dataframe(gets)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-235-0605029dbdef> in <module>
# ----> 1 df=pd.Dataframe(gets)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'
