# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url="https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# %%
data={
    'crtfc_key':'61358a6905345520489a50621766a180b5f8cbc3',
    'corp_code':'00401731',
    'bsns_year':'2018',
    'reprt_code':'11011',
    'fs_div':'CFS'
}

# %%
resp = requests.get(url,params=data)

# %%
data=resp.json()

# %%
data
# Out:
# {'status': '000',
#  'message': '정상',
#  'list': [{'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CurrentAssets',
#    'account_nm': '유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '19362854000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '19194969000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '16990563000000',
#    'ord': '1'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CashAndCashEquivalents',
#    'account_nm': '현금및현금성자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '4270388000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3350597000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3015137000000',
#    'ord': '2'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': '금융기관예치금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '80516000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '80515000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '80559000000',
#    'ord': '3'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermTradeReceivable',
#    'account_nm': '매출채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '6371594000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '8178213000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '7059889000000',
#    'ord': '4'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_TradeAndOtherCurrentReceivables',
#    'account_nm': '기타수취채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '506437000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '467427000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '545766000000',
#    'ord': '5'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_OtherCurrentFinancialAssets',
#    'account_nm': '기타금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '8401000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3534000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '30650000000',
#    'ord': '6'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_Inventories',
#    'account_nm': '재고자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '6021356000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '5908437000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '5171015000000',
#    'ord': '7'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CurrentTaxAssets',
#    'account_nm': '당기법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '151778000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '134159000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '147221000000',
#    'ord': '8'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '계약자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '763776000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '9'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentAssets',
#    'account_nm': '기타자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1073396000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1050651000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '931420000000',
#    'ord': '10'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSaleOrAsHeldForDistributionToOwners',
#    'account_nm': '매각예정분류자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '115212000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '21436000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '8906000000',
#    'ord': '11'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_NoncurrentAssets',
#    'account_nm': '비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '24965589000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '22025990000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '20864706000000',
#    'ord': '12'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': '금융기관예치금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '45853000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '52775000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '58195000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentReceivablesGross',
#    'account_nm': '기타수취채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '452366000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '470216000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '490178000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_OtherNoncurrentFinancialAssets',
#    'account_nm': '기타금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '78072000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '52981000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '66147000000',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_PropertyPlantAndEquipment',
#    'account_nm': '유형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '13333951000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '11800782000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '11222428000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_IntangibleAssetsOtherThanGoodwill',
#    'account_nm': '무형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '3001155000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1854620000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1571087000000',
#    'ord': '17'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_DeferredTaxAssets',
#    'account_nm': '이연법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1410793000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1365367000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1554594000000',
#    'ord': '18'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_InvestmentAccountedForUsingEquityMethod',
#    'account_nm': '관계기업 및 공동기업 투자',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '5537556000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '5620331000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '5104558000000',
#    'ord': '19'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_InvestmentProperty',
#    'account_nm': '투자부동산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '94396000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '95712000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '97031000000',
#    'ord': '20'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_DepositsForSeveranceInsurance',
#    'account_nm': '순확정급여자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '942000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '684000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '730000000',
#    'ord': '21'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '계약자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '221008000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '22'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentAssets',
#    'account_nm': '기타자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '789497000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '712522000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '699758000000',
#    'ord': '23'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_Assets',
#    'account_nm': '자산총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '44328443000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '41220959000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '37855269000000',
#    'ord': '24'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CurrentLiabilities',
#    'account_nm': '유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '17135029000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '17536470000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '15744364000000',
#    'ord': '26'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermTradePayables',
#    'account_nm': '매입채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '7216739000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '8137526000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '6746361000000',
#    'ord': '27'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_ShorttermBorrowings',
#    'account_nm': '차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1405116000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1360756000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1650511000000',
#    'ord': '28'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_TradeAndOtherCurrentPayables',
#    'account_nm': '기타지급채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '3670453000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3522839000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3196735000000',
#    'ord': '29'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_OtherCurrentFinancialLiabilities',
#    'account_nm': '기타금융부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '3343000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2280000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '21115000000',
#    'ord': '30'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CurrentTaxLiabilities',
#    'account_nm': '당기법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '185687000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '100353000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '74263000000',
#    'ord': '31'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_CurrentProvisions',
#    'account_nm': '충당부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '672544000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '649555000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '770967000000',
#    'ord': '32'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '계약부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1119806000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '33'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentLiabilities',
#    'account_nm': '기타부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2861341000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3763161000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3284412000000',
#    'ord': '34'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_NoncurrentLiabilities',
#    'account_nm': '비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '10886507000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '9010805000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '8754163000000',
#    'ord': '35'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermBorrowingsGross',
#    'account_nm': '차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '9496070000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '8089724000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '7008500000000',
#    'ord': '36'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentPayables',
#    'account_nm': '기타지급채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '17995000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '6490000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '7771000000',
#    'ord': '37'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_OtherNoncurrentFinancialLiabilities',
#    'account_nm': '기타금융부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '89267000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '68610000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '73226000000',
#    'ord': '38'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_DeferredTaxLiabilities',
#    'account_nm': '이연법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '127014000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '8759000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '9586000000',
#    'ord': '39'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_PostemploymentBenefitObligations',
#    'account_nm': '순확정급여부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '398611000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '326699000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '511252000000',
#    'ord': '40'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_NoncurrentProvisions',
#    'account_nm': '충당부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '343811000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '298121000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1028298000000',
#    'ord': '41'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '계약부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '23787000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '42'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentLiabilities',
#    'account_nm': '기타부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '389952000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '212402000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '115530000000',
#    'ord': '43'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_Liabilities',
#    'account_nm': '부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '28021536000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '26547275000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '24498527000000',
#    'ord': '44'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_EquityAttributableToOwnersOfParent',
#    'account_nm': '지배기업의 소유주자본',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '14253268000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '13224261000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '11987094000000',
#    'ord': '46'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_IssuedCapital',
#    'account_nm': '자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '904169000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '904169000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '904169000000',
#    'ord': '47'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_SharePremium',
#    'account_nm': '주식발행초과금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '3088179000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3088179000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3088179000000',
#    'ord': '48'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_RetainedEarnings',
#    'account_nm': '이익잉여금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '12075414000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '10964155000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '9233416000000',
#    'ord': '49'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherComprehensiveIncomeLossAccumulatedAmount',
#    'account_nm': '기타포괄손익누계액',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-1604730000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-1522478000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-1028962000000',
#    'ord': '50'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ElementsOfOtherStockholdersEquity',
#    'account_nm': '기타자본구성요소',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-209764000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-209764000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-209708000000',
#    'ord': '51'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_NoncontrollingInterests',
#    'account_nm': '비지배지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2053639000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1449423000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1369648000000',
#    'ord': '52'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '자본총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '16306907000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '14673684000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '13356742000000',
#    'ord': '53'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs_EquityAndLiabilities',
#    'account_nm': '부채와 자본 총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '44328443000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '41220959000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '37855269000000',
#    'ord': '54'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_Revenue',
#    'account_nm': '매출액',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '61341664000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '61396284000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '55367033000000',
#    'ord': '0'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_CostOfSales',
#    'account_nm': '매출원가',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '46260620000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '46737563000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '41630293000000',
#    'ord': '1'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_GrossProfit',
#    'account_nm': '매출총이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '15081044000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '14658721000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '13736740000000',
#    'ord': '2'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_TotalSellingGeneralAdministrativeExpenses',
#    'account_nm': '판매비와관리비',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '12377753000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '12190172000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '12398977000000',
#    'ord': '3'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '판매비',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '7431183000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '7125664000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '6689714000000',
#    'ord': '4'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '관리비',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1341955000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1345606000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1347677000000',
#    'ord': '5'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '연구개발비',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2324022000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2386876000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '2468628000000',
#    'ord': '6'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '서비스비',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1280593000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1332026000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1892958000000',
#    'ord': '7'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OperatingIncomeLoss',
#    'account_nm': '영업이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2703291000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2468549000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1337763000000',
#    'ord': '8'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_FinanceIncome',
#    'account_nm': '금융수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '487370000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '483665000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '490593000000',
#    'ord': '9'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_FinanceCosts',
#    'account_nm': '금융비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '796569000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '831114000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '884051000000',
#    'ord': '10'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '지분법이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-77161000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '667475000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '268738000000',
#    'ord': '11'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OtherGains',
#    'account_nm': '기타영업외수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1251599000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1346607000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1894584000000',
#    'ord': '12'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OtherLosses',
#    'account_nm': '기타영업외비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1559955000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1577070000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '2385910000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_ProfitLossBeforeTax',
#    'account_nm': '법인세비용차감전순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2008575000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2558112000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '721717000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_IncomeTaxExpenseContinuingOperations',
#    'account_nm': '법인세비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '535761000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '688594000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '595402000000',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1472814000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1869518000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '126315000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_ProfitLossAttributableToOwnersOfParent',
#    'account_nm': '지배기업의 소유주지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1240139000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1725774000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '76879000000',
#    'ord': '18'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs_ProfitLossAttributableToNoncontrollingInterests',
#    'account_nm': '비지배지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '232675000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '143744000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '49436000000',
#    'ord': '19'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '보통주 기본주당순이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '6882',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '9579',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '422',
#    'ord': '22'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '우선주 기본주당순이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '6932',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '9629',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '472',
#    'ord': '23'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1472814000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1869518000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '126315000000',
#    'ord': '0'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_OtherComprehensiveIncome',
#    'account_nm': '법인세비용차감후기타포괄이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-140567000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-435822000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '358184000000',
#    'ord': '1'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '후속적으로 당기손익으로 재분류되지 않는 항목 :',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-72555000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '95494000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '226893000000',
#    'ord': '2'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeNetOfTaxGainsLossesOnRemeasurementsOfDefinedBenefitPlans',
#    'account_nm': '순확정급여부채의 재측정요소',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-73882000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '96514000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '182022000000',
#    'ord': '3'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_ShareOfOtherComprehensiveIncomeOfAssociatesAndJointVenturesAccountedForUsingEquityMethodThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '관계기업의 재측정요소에 대한 지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1945000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-1020000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '44871000000',
#    'ord': '4'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타포괄손익-공정가치 측정 금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-618000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '5'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '후속적으로 당기손익으로 재분류될 수 있는 항목 :',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-68012000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-531316000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '131291000000',
#    'ord': '6'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_ShareOfOtherComprehensiveIncomeOfAssociatesAndJointVenturesAccountedForUsingEquityMethodThatWillBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '관계기업 및 공동기업의 기타포괄손익(재측정요소 제외)에 대한 지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-8574000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-98852000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-40011000000',
#    'ord': '7'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_GainsLossesOnCashFlowHedgesNetOfTax',
#    'account_nm': '현금흐름위험회피',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-35551000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '29462000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-2946000000',
#    'ord': '8'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_GainsLossesOnRemeasuringAvailableforsaleFinancialAssetsNetOfTax',
#    'account_nm': '매도가능금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-1180000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-377000000',
#    'ord': '9'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_GainsLossesOnExchangeDifferencesOnTranslationNetOfTax',
#    'account_nm': '해외사업장환산외환차이',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-23887000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-460746000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '174625000000',
#    'ord': '10'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_ComprehensiveIncome',
#    'account_nm': '총포괄이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1332247000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1433696000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '484499000000',
#    'ord': '11'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_ComprehensiveIncomeAttributableToOwnersOfParent',
#    'account_nm': '지배기업의 소유주지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '1098351000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1310108000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '432772000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs_ComprehensiveIncomeAttributableToNoncontrollingInterests',
#    'account_nm': '비지배지분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '233896000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '123588000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '51727000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_CashFlowsFromUsedInOperatingActivities',
#    'account_nm': '영업활동으로 인한 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '4541566000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2166270000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3157990000000',
#    'ord': '0'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_OtherInflowsOutflowsOfCashClassifiedAsOperatingActivities',
#    'account_nm': '영업으로부터 창출된 현금',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '5292811000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2937550000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3979344000000',
#    'ord': '1'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_InterestReceivedClassifiedAsOperatingActivities',
#    'account_nm': '이자의 수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '100503000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '81268000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '77639000000',
#    'ord': '2'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_InterestPaidClassifiedAsOperatingActivities',
#    'account_nm': '이자의 지급',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '425816000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '384446000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '433709000000',
#    'ord': '3'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_DividendsReceivedClassifiedAsOperatingActivities',
#    'account_nm': '배당금의 수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '68717000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '68471000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '71919000000',
#    'ord': '4'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_IncomeTaxesPaidRefundClassifiedAsOperatingActivities',
#    'account_nm': '법인세의 납부',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '494649000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '536573000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '537203000000',
#    'ord': '5'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_CashFlowsFromUsedInInvestingActivities',
#    'account_nm': '투자활동으로 인한 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-4420289000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-2582872000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-2390720000000',
#    'ord': '6'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfFinancialInstruments',
#    'account_nm': '금융기관예치금의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '33742000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '22062000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '32663000000',
#    'ord': '7'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfShortTermLoansAndReceivables',
#    'account_nm': '기타수취채권의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '140267000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '159885000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '139949000000',
#    'ord': '8'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '147541000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '628342000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '103824000000',
#    'ord': '9'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfInvestmentsAccountedForUsingEquityMethod',
#    'account_nm': '관계기업 및 공동기업 투자의 회수 및 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '8000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '51676000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '25000000000',
#    'ord': '10'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs_ProceedsFromSalesOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2751000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '2043000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '2523000000',
#    'ord': '11'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfInvestmentProperty',
#    'account_nm': '투자부동산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
# ...
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '연결재무제표 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '122546000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '116511000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '112299000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|비지배지분 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '49661000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '43626000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '39414000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '72885000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '72885000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '72885000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '72885000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '72885000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '72885000000',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_DividendsPaid',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '13'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '연결재무제표 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-20000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-243000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1055000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|비지배지분 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-20000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-187000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '420000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-56000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '635000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-56000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '635000000',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#    'account_nm': '종속기업에 대한 소유주지분의 변동',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '14'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '연결재무제표 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '420001000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|비지배지분 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '420001000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '15'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '연결재무제표 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '16306907000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '14673684000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '13356742000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|비지배지분 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '2053639000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '1449423000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '1369648000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '14253268000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '13224261000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '11987094000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-209764000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-209764000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-209708000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '-1604730000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '-1522478000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '-1028962000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '12075414000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '10964155000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '9233416000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '904169000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '904169000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '904169000000',
#    'ord': '16'},
#   {'rcept_no': '20190401004344',
#    'reprt_code': '11011',
#    'bsns_year': '2018',
#    'corp_code': '00401731',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#    'thstrm_nm': '제 17 기',
#    'thstrm_amount': '3088179000000',
#    'frmtrm_nm': '제 16 기',
#    'frmtrm_amount': '3088179000000',
#    'bfefrmtrm_nm': '제 15 기',
#    'bfefrmtrm_amount': '3088179000000',
#    'ord': '16'}]}

# %%
data.keys()
# Out:
# dict_keys(['status', 'message', 'list'])

# %%
data['list']
# Out:
# [{'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CurrentAssets',
#   'account_nm': '유동자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '19362854000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '19194969000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '16990563000000',
#   'ord': '1'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CashAndCashEquivalents',
#   'account_nm': '현금및현금성자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '4270388000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3350597000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3015137000000',
#   'ord': '2'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents',
#   'account_nm': '금융기관예치금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '80516000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '80515000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '80559000000',
#   'ord': '3'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_ShortTermTradeReceivable',
#   'account_nm': '매출채권',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '6371594000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '8178213000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '7059889000000',
#   'ord': '4'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_TradeAndOtherCurrentReceivables',
#   'account_nm': '기타수취채권',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '506437000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '467427000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '545766000000',
#   'ord': '5'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_OtherCurrentFinancialAssets',
#   'account_nm': '기타금융자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '8401000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3534000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '30650000000',
#   'ord': '6'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_Inventories',
#   'account_nm': '재고자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '6021356000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '5908437000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '5171015000000',
#   'ord': '7'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CurrentTaxAssets',
#   'account_nm': '당기법인세자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '151778000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '134159000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '147221000000',
#   'ord': '8'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '계약자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '763776000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '9'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_OtherCurrentAssets',
#   'account_nm': '기타자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1073396000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1050651000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '931420000000',
#   'ord': '10'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSaleOrAsHeldForDistributionToOwners',
#   'account_nm': '매각예정분류자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '115212000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '21436000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '8906000000',
#   'ord': '11'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_NoncurrentAssets',
#   'account_nm': '비유동자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '24965589000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '22025990000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '20864706000000',
#   'ord': '12'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_LongTermDepositsNotClassifiedAsCashEquivalents',
#   'account_nm': '금융기관예치금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '45853000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '52775000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '58195000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_LongTermTradeAndOtherNonCurrentReceivablesGross',
#   'account_nm': '기타수취채권',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '452366000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '470216000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '490178000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_OtherNoncurrentFinancialAssets',
#   'account_nm': '기타금융자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '78072000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '52981000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '66147000000',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_PropertyPlantAndEquipment',
#   'account_nm': '유형자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '13333951000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '11800782000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '11222428000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_IntangibleAssetsOtherThanGoodwill',
#   'account_nm': '무형자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '3001155000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1854620000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1571087000000',
#   'ord': '17'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_DeferredTaxAssets',
#   'account_nm': '이연법인세자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1410793000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1365367000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1554594000000',
#   'ord': '18'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_InvestmentAccountedForUsingEquityMethod',
#   'account_nm': '관계기업 및 공동기업 투자',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '5537556000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '5620331000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '5104558000000',
#   'ord': '19'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_InvestmentProperty',
#   'account_nm': '투자부동산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '94396000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '95712000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '97031000000',
#   'ord': '20'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_DepositsForSeveranceInsurance',
#   'account_nm': '순확정급여자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '942000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '684000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '730000000',
#   'ord': '21'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '계약자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '221008000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '22'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_OtherNonCurrentAssets',
#   'account_nm': '기타자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '789497000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '712522000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '699758000000',
#   'ord': '23'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_Assets',
#   'account_nm': '자산총계',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '44328443000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '41220959000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '37855269000000',
#   'ord': '24'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CurrentLiabilities',
#   'account_nm': '유동부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '17135029000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '17536470000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '15744364000000',
#   'ord': '26'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_ShortTermTradePayables',
#   'account_nm': '매입채무',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '7216739000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '8137526000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '6746361000000',
#   'ord': '27'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_ShorttermBorrowings',
#   'account_nm': '차입금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1405116000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1360756000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1650511000000',
#   'ord': '28'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_TradeAndOtherCurrentPayables',
#   'account_nm': '기타지급채무',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '3670453000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3522839000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3196735000000',
#   'ord': '29'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_OtherCurrentFinancialLiabilities',
#   'account_nm': '기타금융부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '3343000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2280000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '21115000000',
#   'ord': '30'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CurrentTaxLiabilities',
#   'account_nm': '당기법인세부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '185687000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '100353000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '74263000000',
#   'ord': '31'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_CurrentProvisions',
#   'account_nm': '충당부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '672544000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '649555000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '770967000000',
#   'ord': '32'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '계약부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1119806000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '33'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_OtherCurrentLiabilities',
#   'account_nm': '기타부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2861341000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3763161000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3284412000000',
#   'ord': '34'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_NoncurrentLiabilities',
#   'account_nm': '비유동부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '10886507000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '9010805000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '8754163000000',
#   'ord': '35'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_LongTermBorrowingsGross',
#   'account_nm': '차입금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '9496070000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '8089724000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '7008500000000',
#   'ord': '36'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_LongTermTradeAndOtherNonCurrentPayables',
#   'account_nm': '기타지급채무',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '17995000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '6490000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '7771000000',
#   'ord': '37'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_OtherNoncurrentFinancialLiabilities',
#   'account_nm': '기타금융부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '89267000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '68610000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '73226000000',
#   'ord': '38'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_DeferredTaxLiabilities',
#   'account_nm': '이연법인세부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '127014000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '8759000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '9586000000',
#   'ord': '39'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_PostemploymentBenefitObligations',
#   'account_nm': '순확정급여부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '398611000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '326699000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '511252000000',
#   'ord': '40'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_NoncurrentProvisions',
#   'account_nm': '충당부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '343811000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '298121000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1028298000000',
#   'ord': '41'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '계약부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '23787000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '42'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_OtherNonCurrentLiabilities',
#   'account_nm': '기타부채',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '389952000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '212402000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '115530000000',
#   'ord': '43'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_Liabilities',
#   'account_nm': '부채총계',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '28021536000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '26547275000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '24498527000000',
#   'ord': '44'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_EquityAttributableToOwnersOfParent',
#   'account_nm': '지배기업의 소유주자본',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '14253268000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '13224261000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '11987094000000',
#   'ord': '46'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_IssuedCapital',
#   'account_nm': '자본금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '904169000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '904169000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '904169000000',
#   'ord': '47'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_SharePremium',
#   'account_nm': '주식발행초과금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '3088179000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3088179000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3088179000000',
#   'ord': '48'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_RetainedEarnings',
#   'account_nm': '이익잉여금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '12075414000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '10964155000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '9233416000000',
#   'ord': '49'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_OtherComprehensiveIncomeLossAccumulatedAmount',
#   'account_nm': '기타포괄손익누계액',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-1604730000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-1522478000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-1028962000000',
#   'ord': '50'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'dart_ElementsOfOtherStockholdersEquity',
#   'account_nm': '기타자본구성요소',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-209764000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-209764000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-209708000000',
#   'ord': '51'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_NoncontrollingInterests',
#   'account_nm': '비지배지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2053639000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1449423000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1369648000000',
#   'ord': '52'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '자본총계',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '16306907000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '14673684000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '13356742000000',
#   'ord': '53'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'BS',
#   'sj_nm': '재무상태표',
#   'account_id': 'ifrs_EquityAndLiabilities',
#   'account_nm': '부채와 자본 총계',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '44328443000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '41220959000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '37855269000000',
#   'ord': '54'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_Revenue',
#   'account_nm': '매출액',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '61341664000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '61396284000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '55367033000000',
#   'ord': '0'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_CostOfSales',
#   'account_nm': '매출원가',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '46260620000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '46737563000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '41630293000000',
#   'ord': '1'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_GrossProfit',
#   'account_nm': '매출총이익',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '15081044000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '14658721000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '13736740000000',
#   'ord': '2'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'dart_TotalSellingGeneralAdministrativeExpenses',
#   'account_nm': '판매비와관리비',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '12377753000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '12190172000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '12398977000000',
#   'ord': '3'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '판매비',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '7431183000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '7125664000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '6689714000000',
#   'ord': '4'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '관리비',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1341955000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1345606000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1347677000000',
#   'ord': '5'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '연구개발비',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2324022000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2386876000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '2468628000000',
#   'ord': '6'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '서비스비',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1280593000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1332026000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1892958000000',
#   'ord': '7'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'dart_OperatingIncomeLoss',
#   'account_nm': '영업이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2703291000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2468549000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1337763000000',
#   'ord': '8'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_FinanceIncome',
#   'account_nm': '금융수익',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '487370000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '483665000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '490593000000',
#   'ord': '9'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_FinanceCosts',
#   'account_nm': '금융비용',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '796569000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '831114000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '884051000000',
#   'ord': '10'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '지분법이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-77161000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '667475000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '268738000000',
#   'ord': '11'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'dart_OtherGains',
#   'account_nm': '기타영업외수익',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1251599000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1346607000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1894584000000',
#   'ord': '12'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'dart_OtherLosses',
#   'account_nm': '기타영업외비용',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1559955000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1577070000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '2385910000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_ProfitLossBeforeTax',
#   'account_nm': '법인세비용차감전순이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2008575000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2558112000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '721717000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_IncomeTaxExpenseContinuingOperations',
#   'account_nm': '법인세비용',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '535761000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '688594000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '595402000000',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_ProfitLoss',
#   'account_nm': '당기순이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1472814000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1869518000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '126315000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_ProfitLossAttributableToOwnersOfParent',
#   'account_nm': '지배기업의 소유주지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1240139000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1725774000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '76879000000',
#   'ord': '18'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': 'ifrs_ProfitLossAttributableToNoncontrollingInterests',
#   'account_nm': '비지배지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '232675000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '143744000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '49436000000',
#   'ord': '19'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '보통주 기본주당순이익',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '6882',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '9579',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '422',
#   'ord': '22'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'IS',
#   'sj_nm': '손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '우선주 기본주당순이익',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '6932',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '9629',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '472',
#   'ord': '23'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_ProfitLoss',
#   'account_nm': '당기순이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1472814000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1869518000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '126315000000',
#   'ord': '0'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_OtherComprehensiveIncome',
#   'account_nm': '법인세비용차감후기타포괄이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-140567000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-435822000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '358184000000',
#   'ord': '1'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'dart_OtherComprehensiveIncomeThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#   'account_nm': '후속적으로 당기손익으로 재분류되지 않는 항목 :',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-72555000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '95494000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '226893000000',
#   'ord': '2'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'dart_OtherComprehensiveIncomeNetOfTaxGainsLossesOnRemeasurementsOfDefinedBenefitPlans',
#   'account_nm': '순확정급여부채의 재측정요소',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-73882000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '96514000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '182022000000',
#   'ord': '3'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'dart_ShareOfOtherComprehensiveIncomeOfAssociatesAndJointVenturesAccountedForUsingEquityMethodThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#   'account_nm': '관계기업의 재측정요소에 대한 지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1945000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-1020000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '44871000000',
#   'ord': '4'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '기타포괄손익-공정가치 측정 금융자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-618000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '5'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'dart_OtherComprehensiveIncomeThatWillBeReclassifiedToProfitOrLossNetOfTax',
#   'account_nm': '후속적으로 당기손익으로 재분류될 수 있는 항목 :',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-68012000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-531316000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '131291000000',
#   'ord': '6'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'dart_ShareOfOtherComprehensiveIncomeOfAssociatesAndJointVenturesAccountedForUsingEquityMethodThatWillBeReclassifiedToProfitOrLossNetOfTax',
#   'account_nm': '관계기업 및 공동기업의 기타포괄손익(재측정요소 제외)에 대한 지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-8574000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-98852000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-40011000000',
#   'ord': '7'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_GainsLossesOnCashFlowHedgesNetOfTax',
#   'account_nm': '현금흐름위험회피',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-35551000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '29462000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-2946000000',
#   'ord': '8'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_GainsLossesOnRemeasuringAvailableforsaleFinancialAssetsNetOfTax',
#   'account_nm': '매도가능금융자산',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-1180000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-377000000',
#   'ord': '9'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_GainsLossesOnExchangeDifferencesOnTranslationNetOfTax',
#   'account_nm': '해외사업장환산외환차이',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-23887000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-460746000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '174625000000',
#   'ord': '10'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_ComprehensiveIncome',
#   'account_nm': '총포괄이익(손실)',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1332247000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1433696000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '484499000000',
#   'ord': '11'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_ComprehensiveIncomeAttributableToOwnersOfParent',
#   'account_nm': '지배기업의 소유주지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '1098351000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1310108000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '432772000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CIS',
#   'sj_nm': '포괄손익계산서',
#   'account_id': 'ifrs_ComprehensiveIncomeAttributableToNoncontrollingInterests',
#   'account_nm': '비지배지분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '233896000000',
#   'thstrm_add_amount': '',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '123588000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '51727000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_CashFlowsFromUsedInOperatingActivities',
#   'account_nm': '영업활동으로 인한 현금흐름',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '4541566000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2166270000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3157990000000',
#   'ord': '0'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_OtherInflowsOutflowsOfCashClassifiedAsOperatingActivities',
#   'account_nm': '영업으로부터 창출된 현금',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '5292811000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2937550000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3979344000000',
#   'ord': '1'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_InterestReceivedClassifiedAsOperatingActivities',
#   'account_nm': '이자의 수취',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '100503000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '81268000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '77639000000',
#   'ord': '2'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_InterestPaidClassifiedAsOperatingActivities',
#   'account_nm': '이자의 지급',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '425816000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '384446000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '433709000000',
#   'ord': '3'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_DividendsReceivedClassifiedAsOperatingActivities',
#   'account_nm': '배당금의 수취',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '68717000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '68471000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '71919000000',
#   'ord': '4'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_IncomeTaxesPaidRefundClassifiedAsOperatingActivities',
#   'account_nm': '법인세의 납부',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '494649000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '536573000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '537203000000',
#   'ord': '5'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_CashFlowsFromUsedInInvestingActivities',
#   'account_nm': '투자활동으로 인한 현금흐름',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-4420289000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-2582872000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-2390720000000',
#   'ord': '6'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_ProceedsFromSalesOfFinancialInstruments',
#   'account_nm': '금융기관예치금의 감소',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '33742000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '22062000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '32663000000',
#   'ord': '7'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_ProceedsFromSalesOfShortTermLoansAndReceivables',
#   'account_nm': '기타수취채권의 감소',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '140267000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '159885000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '139949000000',
#   'ord': '8'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#   'account_nm': '유형자산의 처분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '147541000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '628342000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '103824000000',
#   'ord': '9'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_ProceedsFromSalesOfInvestmentsAccountedForUsingEquityMethod',
#   'account_nm': '관계기업 및 공동기업 투자의 회수 및 처분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '8000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '51676000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '25000000000',
#   'ord': '10'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'ifrs_ProceedsFromSalesOfIntangibleAssetsClassifiedAsInvestingActivities',
#   'account_nm': '무형자산의 처분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2751000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '2043000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '2523000000',
#   'ord': '11'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_ProceedsFromSalesOfInvestmentProperty',
#   'account_nm': '투자부동산의 처분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '21853000000',
#   'ord': '12'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_ProceedsFromSalesOfNonCurrentAssetsOrDisposalGroupsClassifiedAsHeldForSale',
#   'account_nm': '매각예정분류자산의 처분',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '39092000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '12710000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '4328000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '사업양도',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '49618000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '13942000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '6535000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '기타의 감소',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '47000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '133000000',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'CF',
#   'sj_nm': '현금흐름표',
#   'account_id': 'dart_PurchaseOfFinancialInstruments',
#   'account_nm': '금융기관예치금의 증가',
#   'account_detail': '-',
#   'thstrm_nm': '제 17 기',
# ...
#   'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '12'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': '-표준계정코드 미사용-',
#   'account_nm': '해외사업장환산외환차이',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '12'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '연결재무제표 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '122546000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '116511000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '112299000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|비지배지분 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '49661000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '43626000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '39414000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '72885000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '72885000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '72885000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '72885000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '72885000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '72885000000',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_DividendsPaid',
#   'account_nm': '연차배당',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '13'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '연결재무제표 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-20000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-243000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1055000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|비지배지분 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-20000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-187000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '420000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-56000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '635000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-56000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '635000000',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_IncreaseDecreaseThroughChangesInOwnershipInterestsInSubsidiariesThatDoNotResultInLossOfControl',
#   'account_nm': '종속기업에 대한 소유주지분의 변동',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '14'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '연결재무제표 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '420001000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|비지배지분 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '420001000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#   'account_nm': '사업결합',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '0',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '0',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '0',
#   'ord': '15'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '연결재무제표 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '16306907000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '14673684000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '13356742000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|비지배지분 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '2053639000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '1449423000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '1369648000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '14253268000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '13224261000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '11987094000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타자본구성요소 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-209764000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-209764000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-209708000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|기타포괄손익누계액 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '-1604730000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '-1522478000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '-1028962000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|이익잉여금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '12075414000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '10964155000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '9233416000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|자본금 [member]',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '904169000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '904169000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '904169000000',
#   'ord': '16'},
#  {'rcept_no': '20190401004344',
#   'reprt_code': '11011',
#   'bsns_year': '2018',
#   'corp_code': '00401731',
#   'sj_div': 'SCE',
#   'sj_nm': '자본변동표',
#   'account_id': 'ifrs_Equity',
#   'account_nm': '기말자본',
#   'account_detail': '자본 [member]|지배기업의 소유주지분|주식발행초과금',
#   'thstrm_nm': '제 17 기',
#   'thstrm_amount': '3088179000000',
#   'frmtrm_nm': '제 16 기',
#   'frmtrm_amount': '3088179000000',
#   'bfefrmtrm_nm': '제 15 기',
#   'bfefrmtrm_amount': '3088179000000',
#   'ord': '16'}]

# %%
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile
import urllib

# %%
urllib.parse.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-0ebee28fd0b2> in <module>
# ----> 1 urllib.parse()
#
# TypeError: 'module' object is not callable

# %%
url = 'https://opendart.fss.or.kr/api/fnlttSinglAcnt.xml'
data={
    'crtfc_key':'61358a6905345520489a50621766a180b5f8cbc3',
    'corp_code':'00401731',
    'bsns_year':'2018',
    'reprt_code':'11011',
    'fs_div':'CFS'
}
with requests.get(url,params=data) as zipresp:
    with ZipFile(BytesIO(zipresp.initial_bytes()) as zfile:
        zfile.extractall('corp_num')
# Out:
#   File "<ipython-input-29-22ae7a3403d0>", line 10
#     with ZipFile(BytesIO(zipresp.initial_bytes()) as zfile:
#                                                    ^
# SyntaxError: invalid syntax
