# %% [markdown]
# ## 데이터프레임의 문자열데이터 다루기

# %%
import pandas as pd
import shutil

# %%
# shutil.move ('C:/Users/i7B/Downloads/주가데이터.xlsx','주가데이터.xlsx')
# Out:
# '주가데이터.xlsx'

# %%
df=pd.read_excel('주가데이터.xlsx')

# %%
df.head()
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0 2018-07-02  10100   600  10850  10900  10000  137977
# 1 2018-06-29  10700   300  10550  10900   9990  170253
# 2 2018-06-28  10400   500  10900  10950  10150  155769
# 3 2018-06-27  10900   100  10800  11050  10500  133548
# 4 2018-06-26  10800   350  10900  11000  10700   63039

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연월일     20 non-null     datetime64[ns]
#  1   당일종가    20 non-null     int64
#  2   전일종가    20 non-null     int64
#  3   시가      20 non-null     int64
#  4   고가      20 non-null     int64
#  5   저가      20 non-null     int64
#  6   거래량     20 non-null     int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 1.2 KB

# %%
df['연월일']=df['연월일'].astype('str')

# %%
datas=df['연월일'].str.split('-')

# %%
datas
# Out:
# 0     [2018, 07, 02]
# 1     [2018, 06, 29]
# 2     [2018, 06, 28]
# 3     [2018, 06, 27]
# 4     [2018, 06, 26]
# 5     [2018, 06, 25]
# 6     [2018, 06, 22]
# 7     [2018, 06, 21]
# 8     [2018, 06, 20]
# 9     [2018, 06, 19]
# 10    [2018, 06, 18]
# 11    [2018, 06, 15]
# 12    [2018, 06, 14]
# 13    [2018, 06, 12]
# 14    [2018, 06, 11]
# 15    [2018, 06, 08]
# 16    [2018, 06, 07]
# 17    [2018, 06, 05]
# 18    [2018, 06, 04]
# 19    [2018, 06, 01]
# Name: 연월일, dtype: object

# %%
df['연']=datas.str.get(0)

# %%
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     연
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018
# 1  2018-06-29  10700   300  10550  10900   9990  170253  2018
# 2  2018-06-28  10400   500  10900  10950  10150  155769  2018
# 3  2018-06-27  10900   100  10800  11050  10500  133548  2018
# 4  2018-06-26  10800   350  10900  11000  10700   63039  2018

# %%
df['월']=datas.str.get(1)
df['일']=datas.str.get(2)

# %%
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     연   월   일
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018  07  02
# 1  2018-06-29  10700   300  10550  10900   9990  170253  2018  06  29
# 2  2018-06-28  10400   500  10900  10950  10150  155769  2018  06  28
# 3  2018-06-27  10900   100  10800  11050  10500  133548  2018  06  27
# 4  2018-06-26  10800   350  10900  11000  10700   63039  2018  06  26

# %%
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_teenage=titanic[(titanic['age']>=10) &(titanic['age']<19)]

# %%
df_teenage
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 22          1       3  female  15.0      0      0   8.0292        Q   Third
# 38          0       3  female  18.0      2      0  18.0000        S   Third
# 39          1       3  female  14.0      1      0  11.2417        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 841         0       2    male  16.0      0      0  10.5000        S  Second
# 844         0       3    male  17.0      0      0   8.6625        S   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 855         1       3  female  18.0      0      1   9.3500        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic['age']>=20) &(titanic['age']<29) & (titanic['sex']=='female')].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 41         0       2  female  27.0      1      0   21.0000        S  Second
# 56         1       2  female  21.0      0      0   10.5000        S  Second
# 88         1       1  female  23.0      3      2  263.0000        S   First
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 41  woman       False  NaN  Southampton    no  False
# 56  woman       False  NaN  Southampton   yes   True
# 88  woman       False    C  Southampton   yes  False

# %%
titanic[((titanic['age']>=20) &(titanic['age']<29)) & (titanic['sex']=='female')].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 41         0       2  female  27.0      1      0   21.0000        S  Second
# 56         1       2  female  21.0      0      0   10.5000        S  Second
# 88         1       1  female  23.0      3      2  263.0000        S   First
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 41  woman       False  NaN  Southampton    no  False
# 56  woman       False  NaN  Southampton   yes   True
# 88  woman       False    C  Southampton   yes  False

# %%
pd.set_option('display.max_columns',19)
titanic=sns.load_dataset('titanic')
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
mask1=titanic['sibsp']==3
mask2=titanic['sibsp']==4
mask3=titanic['sibsp']==5

# %%
df_boolean=titanic[mask1|mask2|mask3]

# %%
df_boolean.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 7          0       3    male   2.0      3      1   21.0750        S  Third
# 16         0       3    male   2.0      4      1   29.1250        Q  Third
# 24         0       3  female   8.0      3      1   21.0750        S  Third
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 50         0       3    male   7.0      4      1   39.6875        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 24  child       False  NaN  Southampton    no  False
# 27    man        True    C  Southampton    no  False
# 50  child       False  NaN  Southampton    no  False

# %%
isin_filter=titanic['sibsp'].isin([3,4,5])

# %%
df_isin=titanic[isin_filter]

# %%
df_isin.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 7          0       3    male   2.0      3      1   21.0750        S  Third
# 16         0       3    male   2.0      4      1   29.1250        Q  Third
# 24         0       3  female   8.0      3      1   21.0750        S  Third
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 50         0       3    male   7.0      4      1   39.6875        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 24  child       False  NaN  Southampton    no  False
# 27    man        True    C  Southampton    no  False
# 50  child       False  NaN  Southampton    no  False
